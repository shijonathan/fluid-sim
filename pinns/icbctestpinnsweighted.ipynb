# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import matplotlib.animation as animation
import os

from collections import OrderedDict

# %%
# define parameters
hidden_layers = 2
nodes_per_layer = 700

# define output directory
sim_type = 'lid_cavity'
out_dir = os.path.join('results', '%dnode%dlayer' % (nodes_per_layer, hidden_layers), sim_type)

if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.layers = [3] + [nodes_per_layer for _ in range(hidden_layers)] + [2]
        self.depth = len(self.layers) - 1

        self.activation = nn.Tanh

        layer_list = list()
        for i in range(self.depth - 1):
            layer_list.append(('layer_%d' % i, torch.nn.Linear(self.layers[i], self.layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))

        layer_list.append(('layer_%d' % (self.depth - 1), nn.Linear(self.layers[-2], self.layers[-1])))

        layerDict = OrderedDict(layer_list)
        self.model = nn.Sequential(layerDict)
        self.model.apply(self.init_weights)

    # Xavier initilization
    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.constant_(m.bias, 0.0)

    def forward(self, x):
        out = self.model(x)
        return out

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
nu = 0.01/np.pi

class NS:
    def __init__(self, X, Y, T, u, v):
        self.x = torch.tensor(X, dtype=torch.float32, requires_grad=True).to(device)
        self.y = torch.tensor(Y, dtype=torch.float32, requires_grad=True).to(device)
        self.t = torch.tensor(T, dtype=torch.float32, requires_grad=True).to(device)

        self.u = torch.tensor(u, dtype=torch.float32).to(device)
        self.v = torch.tensor(v, dtype=torch.float32).to(device)

        self.null = torch.zeros((self.x.shape[0], 1)).to(device)
        
        self.net = DNN().to(device)

        # track loss history
        self.loss_history = []
        self.loss_history_u = []
        self.loss_history_v = []
        self.loss_history_f = []
        self.loss_history_g = []

        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=1e-3)

        # self.optimizer = torch.optim.LBFGS(self.net.parameters(), lr=1, max_iter=200000, max_eval=50000, 
        #                                    history_size=50, tolerance_grad=1e-5, tolerance_change=0.5 * np.finfo(float).eps, line_search_fn="strong_wolfe")
        
        self.mse = nn.MSELoss().to(device)

        self.ls = 0
        self.iter = 0

    def function(self, x, y, t):
        res = self.net(torch.hstack((x, y, t)))
        psi, p = res[:, 0:1], res[:, 1:2]

        u = torch.autograd.grad(psi, y, grad_outputs=torch.ones_like(psi), 
                                create_graph=True)[0]
        v = -1.*torch.autograd.grad(psi, x, grad_outputs=torch.ones_like(psi), 
                                    create_graph=True)[0]

        u_x = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), 
                                  create_graph=True)[0]
        u_xx = torch.autograd.grad(u_x, x, grad_outputs=torch.ones_like(u_x), 
                                   create_graph=True)[0]
        u_y = torch.autograd.grad(u, y, grad_outputs=torch.ones_like(u), 
                                  create_graph=True)[0]
        u_yy = torch.autograd.grad(u_y, y, grad_outputs=torch.ones_like(u_y), 
                                   create_graph=True)[0]
        u_t = torch.autograd.grad(u, t, grad_outputs=torch.ones_like(u), 
                                  create_graph=True)[0]

        v_x = torch.autograd.grad(v, x, grad_outputs=torch.ones_like(v), 
                                  create_graph=True)[0]
        v_xx = torch.autograd.grad(v_x, x, grad_outputs=torch.ones_like(v_x), 
                                   create_graph=True)[0]
        v_y = torch.autograd.grad(v, y, grad_outputs=torch.ones_like(v), 
                                  create_graph=True)[0]
        v_yy = torch.autograd.grad(v_y, y, grad_outputs=torch.ones_like(v_y), 
                                   create_graph=True)[0]
        v_t = torch.autograd.grad(v, t, grad_outputs=torch.ones_like(v), 
                                  create_graph=True)[0]

        p_x = torch.autograd.grad(p, x, grad_outputs=torch.ones_like(p), 
                                  create_graph=True)[0]
        p_y = torch.autograd.grad(p, y, grad_outputs=torch.ones_like(p), 
                                  create_graph=True)[0]

        f = u_t + u * u_x + v * u_y + p_x - nu * (u_xx + u_yy)
        g = v_t + u * v_x + v * v_y + p_y - nu * (v_xx + v_yy)

        return u, v, p, f, g
    
    def closure(self):
        self.optimizer.zero_grad()

        u_pred, v_pred, p_pred, f_pred, g_pred = self.function(self.x, self.y, self.t)

        u_loss = self.mse(u_pred, self.u)
        v_loss = self.mse(v_pred, self.v)
        f_loss = self.mse(f_pred, self.null)
        g_loss = self.mse(g_pred, self.null)

        self.ls = u_loss + v_loss + 50 * f_loss + 50 * g_loss

        self.loss_history.append(self.ls.detach().cpu().numpy())
        self.loss_history_u.append(u_loss.detach().cpu().numpy())
        self.loss_history_v.append(v_loss.detach().cpu().numpy())
        self.loss_history_f.append(f_loss.detach().cpu().numpy())
        self.loss_history_g.append(g_loss.detach().cpu().numpy())

        self.ls.backward()

        self.iter += 1
        if not self.iter % 1: 
            print('Iteration: {:}, Loss: {:0.6f}'.format(self.iter, self.ls))

        return self.ls
    
    def train(self):
        # Adam training
        while self.iter < 100:
            self.net.train()
            self.optimizer.step(self.closure)
        
        # L-BFGS training
        if self.iter == 100:
            print('--------Switching optimizer--------')
            print(self.optimizer)
            self.optimizer = torch.optim.LBFGS(self.net.parameters(), lr=1, max_iter=200000, max_eval=50000,history_size=50, tolerance_grad=1e-5, tolerance_change=0.5 * np.finfo(float).eps, line_search_fn="strong_wolfe")
            print(self.optimizer)
            print('-----------------------------------')
        self.net.train()
        self.optimizer.step(self.closure)

# %%
N_train = 5000
nu = 0.01 # Reynold's number

data = scipy.io.loadmat('C:\\Users\\Administrator\\Documents\\research\\fluid-sim\\data\\2d_navierstokes.mat')

usol = data['usol'] # sqrt(N) x sqrt(N) x T
vsol = data['vsol'] # sqrt(N) x sqrt(N) x T
psol = data['psol'] # sqrt(N) x sqrt(N) x T

# cut off first entries from usol, vsol, and psol because it is empty
usol = usol[:, :89, 1:] # cut off an extra row in y dimension
vsol = vsol[:89, :, 1:] # cut off an extra row in x dimension 
psol = psol[:89, :89, 1:]

x = np.arange(0, 1, 1/90)[:89]
y = np.arange(0, 1, 1/90)[:89]
t = np.arange(0, 4, 0.01).reshape(-1, 1)[:399]

X, Y, T = np.meshgrid(x, y, t, indexing='ij')
X = X.reshape(-1, 1)
Y = Y.reshape(-1, 1)
T = T.reshape(-1, 1)
X_star = np.concatenate((X, Y, T), axis=1).reshape(89, 89, 399, 3)

N = X_star.shape[0] * X_star.shape[1]
T = t.shape[0]

x_bc = np.concatenate((X_star[:, 0, :], X_star[:, -1, :], X_star[0, 1:-1, :], X_star[-1, 1:-1, :]), axis=0)
x_ic = X_star[:, :, 0].reshape(N, 3) # positions
x_bc = x_bc.reshape(x_bc.shape[0] * x_bc.shape[1], x_bc.shape[2])
x_icbc = np.vstack((x_ic, x_bc))

# usol = np.reshape(usol, (N, T)) # N x T
# vsol = np.reshape(vsol, (N, T)) # N x T
# psol = np.reshape(psol, (N, T)) # N x T

# XX = np.tile(X_star[:, 0:1], (1, usol.shape[1])) # N x T
# YY = np.tile(X_star[:, 1:2], (1, usol.shape[1])) # N x T
# TT = np.tile(t, (1, X_star.shape[0])).T # N x T

# flatten all inputs
# x = XX.flatten()[:, None] # NT x 1
# y = YY.flatten()[:, None] # NT x 1
# t = TT.flatten()[:, None] # NT x 1

# u = usol.flatten()[:, None] # NT x 1
# v = vsol.flatten()[:, None] # NT x 1
# p = psol.flatten()[:, None] # NT x 1

# extract initial and boundary conditions
u_ic = usol[:, :, 0]
u_bc = np.concatenate((usol[:, 0, :], usol[:, -1, :], usol[0, 1:-1, :], usol[-1, 1:-1, :]), axis=0)
u_icbc = np.hstack((u_ic.flatten(), u_bc.flatten())).reshape(-1, 1)

v_ic = vsol[:, :, 0]
v_bc = np.concatenate((vsol[:, 0, :], vsol[:, -1, :], vsol[0, 1:-1, :], vsol[-1, 1:-1, :]), axis=0)
v_icbc = np.hstack((v_ic.flatten(), v_bc.flatten())).reshape(-1, 1)

idx = np.random.choice(u_icbc.shape[0], N_train, replace=False)
x_train = x_icbc[idx][:, 0].reshape(-1, 1)
y_train = x_icbc[idx][:, 1].reshape(-1, 1)
t_train = x_icbc[idx][:, 2].reshape(-1, 1)

u_train = u_icbc[idx, :]
v_train = v_icbc[idx, :]
# p_train = p[idx, :]

# %%
PINN = NS(x_train, y_train, t_train, u_train, v_train)
PINN.train()
# Out:
# Iteration: 1, Loss: 1.265625
# Iteration: 2, Loss: 38.002472
# Iteration: 3, Loss: 3.364430
# Iteration: 4, Loss: 6.802324
# Iteration: 5, Loss: 18.787502
# Iteration: 6, Loss: 13.590469
# Iteration: 7, Loss: 3.614953
# Iteration: 8, Loss: 0.175534
# Iteration: 9, Loss: 3.905709
# Iteration: 10, Loss: 8.039573
# Iteration: 11, Loss: 7.872619
# Iteration: 12, Loss: 4.393789
# Iteration: 13, Loss: 1.037039
# Iteration: 14, Loss: 0.171556
# Iteration: 15, Loss: 1.592831
# Iteration: 16, Loss: 3.408796
# Iteration: 17, Loss: 3.949900
# Iteration: 18, Loss: 2.929086
# Iteration: 19, Loss: 1.309510
# Iteration: 20, Loss: 0.250820
# Iteration: 21, Loss: 0.242598
# Iteration: 22, Loss: 0.978985
# Iteration: 23, Loss: 1.715326
# Iteration: 24, Loss: 1.865682
# Iteration: 25, Loss: 1.391407
# Iteration: 26, Loss: 0.675436
# Iteration: 27, Loss: 0.184490
# Iteration: 28, Loss: 0.158965
# Iteration: 29, Loss: 0.480271
# Iteration: 30, Loss: 0.831130
# Iteration: 31, Loss: 0.943053
# Iteration: 32, Loss: 0.752639
# Iteration: 33, Loss: 0.418492
# Iteration: 34, Loss: 0.166136
# Iteration: 35, Loss: 0.122803
# Iteration: 36, Loss: 0.261752
# Iteration: 37, Loss: 0.437861
# Iteration: 38, Loss: 0.508806
# Iteration: 39, Loss: 0.433633
# Iteration: 40, Loss: 0.274737
# Iteration: 41, Loss: 0.143885
# Iteration: 42, Loss: 0.115293
# Iteration: 43, Loss: 0.179043
# Iteration: 44, Loss: 0.267090
# Iteration: 45, Loss: 0.305164
# Iteration: 46, Loss: 0.267972
# Iteration: 47, Loss: 0.189324
# Iteration: 48, Loss: 0.125201
# Iteration: 49, Loss: 0.113859
# Iteration: 50, Loss: 0.148924
# Iteration: 51, Loss: 0.192059
# Iteration: 52, Loss: 0.207056
# Iteration: 53, Loss: 0.183581
# Iteration: 54, Loss: 0.142688
# Iteration: 55, Loss: 0.114502
# Iteration: 56, Loss: 0.114772
# Iteration: 57, Loss: 0.136086
# Iteration: 58, Loss: 0.155925
# Iteration: 59, Loss: 0.157652
# Iteration: 60, Loss: 0.141063
# Iteration: 61, Loss: 0.120404
# Iteration: 62, Loss: 0.110959
# Iteration: 63, Loss: 0.116452
# Iteration: 64, Loss: 0.128826
# Iteration: 65, Loss: 0.135697
# Iteration: 66, Loss: 0.131576
# Iteration: 67, Loss: 0.120683
# Iteration: 68, Loss: 0.112048
# Iteration: 69, Loss: 0.111546
# Iteration: 70, Loss: 0.117281
# Iteration: 71, Loss: 0.122861
# Iteration: 72, Loss: 0.122975
# Iteration: 73, Loss: 0.117991
# Iteration: 74, Loss: 0.112438
# Iteration: 75, Loss: 0.110628
# Iteration: 76, Loss: 0.113022
# Iteration: 77, Loss: 0.116398
# Iteration: 78, Loss: 0.117373
# Iteration: 79, Loss: 0.115155
# Iteration: 80, Loss: 0.111988
# Iteration: 81, Loss: 0.110497
# Iteration: 82, Loss: 0.111475
# Iteration: 83, Loss: 0.113370
# Iteration: 84, Loss: 0.114136
# Iteration: 85, Loss: 0.113096
# Iteration: 86, Loss: 0.111331
# Iteration: 87, Loss: 0.110416
# Iteration: 88, Loss: 0.110874
# Iteration: 89, Loss: 0.111920
# Iteration: 90, Loss: 0.112351
# Iteration: 91, Loss: 0.111780
# Iteration: 92, Loss: 0.110800
# Iteration: 93, Loss: 0.110317
# Iteration: 94, Loss: 0.110595
# Iteration: 95, Loss: 0.111165
# Iteration: 96, Loss: 0.111350
# Iteration: 97, Loss: 0.110981
# Iteration: 98, Loss: 0.110441
# Iteration: 99, Loss: 0.110225
# Iteration: 100, Loss: 0.110425
# --------Switching optimizer--------
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# LBFGS (
# Parameter Group 0
#     history_size: 50
#     line_search_fn: strong_wolfe
#     lr: 1
#     max_eval: 50000
#     max_iter: 200000
#     tolerance_change: 1.1102230246251565e-16
#     tolerance_grad: 1e-05
# )
# -----------------------------------
# Iteration: 101, Loss: 0.110723
# Iteration: 102, Loss: 0.110459
# Iteration: 103, Loss: 0.110197
# Iteration: 104, Loss: 0.110196
# Iteration: 105, Loss: 0.110184
# Iteration: 106, Loss: 0.110166
# Iteration: 107, Loss: 0.110141
# Iteration: 108, Loss: 0.110125
# Iteration: 109, Loss: 0.110094
# Iteration: 110, Loss: 0.110035
# Iteration: 111, Loss: 0.109887
# Iteration: 112, Loss: 0.109575
# Iteration: 113, Loss: 0.109032
# Iteration: 114, Loss: 0.108368
# Iteration: 115, Loss: 0.108117
# Iteration: 116, Loss: 0.108061
# Iteration: 117, Loss: 0.107925
# Iteration: 118, Loss: 0.107487
# Iteration: 119, Loss: 0.106821
# Iteration: 120, Loss: 0.105973
# Iteration: 121, Loss: 0.105552
# Iteration: 122, Loss: 0.105154
# Iteration: 123, Loss: 0.105065
# Iteration: 124, Loss: 0.105041
# Iteration: 125, Loss: 0.104979
# Iteration: 126, Loss: 0.104809
# Iteration: 127, Loss: 0.104705
# Iteration: 128, Loss: 0.104517
# Iteration: 129, Loss: 0.104082
# Iteration: 130, Loss: 0.103505
# Iteration: 131, Loss: 0.102948
# Iteration: 132, Loss: 0.102338
# Iteration: 133, Loss: 0.100980
# Iteration: 134, Loss: 0.099301
# Iteration: 135, Loss: 0.097717
# Iteration: 136, Loss: 0.097134
# Iteration: 137, Loss: 0.097023
# Iteration: 138, Loss: 0.096458
# Iteration: 139, Loss: 0.096369
# Iteration: 140, Loss: 0.095998
# Iteration: 141, Loss: 0.094601
# Iteration: 142, Loss: 0.089908
# Iteration: 143, Loss: 0.088849
# Iteration: 144, Loss: 0.086235
# Iteration: 145, Loss: 0.084468
# Iteration: 146, Loss: 0.080798
# Iteration: 147, Loss: 0.081166
# Iteration: 148, Loss: 0.079501
# Iteration: 149, Loss: 0.078391
# Iteration: 150, Loss: 0.077763
# Iteration: 151, Loss: 0.077289
# Iteration: 152, Loss: 0.074294
# Iteration: 153, Loss: 0.071091
# Iteration: 154, Loss: 0.070030
# Iteration: 155, Loss: 0.069471
# Iteration: 156, Loss: 0.069201
# Iteration: 157, Loss: 0.069108
# Iteration: 158, Loss: 0.069056
# Iteration: 159, Loss: 0.068963
# Iteration: 160, Loss: 0.068674
# Iteration: 161, Loss: 0.068252
# Iteration: 162, Loss: 0.067402
# Iteration: 163, Loss: 0.066242
# Iteration: 164, Loss: 0.065218
# Iteration: 165, Loss: 0.065002
# Iteration: 166, Loss: 0.064807
# Iteration: 167, Loss: 0.064772
# Iteration: 168, Loss: 0.064757
# Iteration: 169, Loss: 0.064731
# Iteration: 170, Loss: 0.064610
# Iteration: 171, Loss: 0.064443
# Iteration: 172, Loss: 0.063979
# Iteration: 173, Loss: 0.063176
# Iteration: 174, Loss: 0.062757
# Iteration: 175, Loss: 0.062469
# Iteration: 176, Loss: 0.062719
# Iteration: 177, Loss: 0.062392
# Iteration: 178, Loss: 0.062331
# Iteration: 179, Loss: 0.062307
# Iteration: 180, Loss: 0.062286
# Iteration: 181, Loss: 0.062257
# Iteration: 182, Loss: 0.062197
# Iteration: 183, Loss: 0.062056
# Iteration: 184, Loss: 0.061957
# Iteration: 185, Loss: 0.061869
# Iteration: 186, Loss: 0.061783
# Iteration: 187, Loss: 0.061602
# Iteration: 188, Loss: 0.061526
# Iteration: 189, Loss: 0.061289
# Iteration: 190, Loss: 0.061159
# Iteration: 191, Loss: 0.060924
# Iteration: 192, Loss: 0.060737
# Iteration: 193, Loss: 0.060326
# Iteration: 194, Loss: 0.059900
# Iteration: 195, Loss: 0.059779
# Iteration: 196, Loss: 0.059552
# Iteration: 197, Loss: 0.059698
# Iteration: 198, Loss: 0.059439
# Iteration: 199, Loss: 0.059288
# Iteration: 200, Loss: 0.059222
# Iteration: 201, Loss: 0.059124
# Iteration: 202, Loss: 0.058947
# Iteration: 203, Loss: 0.058758
# Iteration: 204, Loss: 0.058231
# Iteration: 205, Loss: 0.058290
# Iteration: 206, Loss: 0.057980
# Iteration: 207, Loss: 0.057492
# Iteration: 208, Loss: 0.056997
# Iteration: 209, Loss: 0.056570
# Iteration: 210, Loss: 0.056105
# Iteration: 211, Loss: 0.058666
# Iteration: 212, Loss: 0.055703
# Iteration: 213, Loss: 0.058861
# Iteration: 214, Loss: 0.054847
# Iteration: 215, Loss: 0.054405
# Iteration: 216, Loss: 0.054163
# Iteration: 217, Loss: 0.053552
# Iteration: 218, Loss: 0.053500
# Iteration: 219, Loss: 0.053163
# Iteration: 220, Loss: 0.052980
# Iteration: 221, Loss: 0.052598
# Iteration: 222, Loss: 0.052108
# Iteration: 223, Loss: 0.051593
# Iteration: 224, Loss: 0.051376
# Iteration: 225, Loss: 0.051168
# Iteration: 226, Loss: 0.050985
# Iteration: 227, Loss: 0.050641
# Iteration: 228, Loss: 0.050486
# Iteration: 229, Loss: 0.050341
# Iteration: 230, Loss: 0.050204
# Iteration: 231, Loss: 0.049989
# Iteration: 232, Loss: 0.049771
# Iteration: 233, Loss: 0.049647
# Iteration: 234, Loss: 0.049576
# Iteration: 235, Loss: 0.049472
# Iteration: 236, Loss: 0.050304
# Iteration: 237, Loss: 0.049282
# Iteration: 238, Loss: 0.049018
# Iteration: 239, Loss: 0.048844
# Iteration: 240, Loss: 0.048945
# Iteration: 241, Loss: 0.048734
# Iteration: 242, Loss: 0.048704
# Iteration: 243, Loss: 0.048531
# Iteration: 244, Loss: 0.048483
# Iteration: 245, Loss: 0.048427
# Iteration: 246, Loss: 0.048376
# Iteration: 247, Loss: 0.048334
# Iteration: 248, Loss: 0.048172
# Iteration: 249, Loss: 0.047908
# Iteration: 250, Loss: 0.047647
# Iteration: 251, Loss: 0.047404
# Iteration: 252, Loss: 0.047267
# Iteration: 253, Loss: 0.047230
# Iteration: 254, Loss: 0.047209
# Iteration: 255, Loss: 0.047195
# Iteration: 256, Loss: 0.047182
# Iteration: 257, Loss: 0.047150
# Iteration: 258, Loss: 0.047083
# Iteration: 259, Loss: 0.047000
# Iteration: 260, Loss: 0.046884
# Iteration: 261, Loss: 0.046839
# Iteration: 262, Loss: 0.046807
# Iteration: 263, Loss: 0.046768
# Iteration: 264, Loss: 0.046691
# Iteration: 265, Loss: 0.046600
# Iteration: 266, Loss: 0.046496
# Iteration: 267, Loss: 0.046394
# Iteration: 268, Loss: 0.046408
# Iteration: 269, Loss: 0.046369
# Iteration: 270, Loss: 0.046339
# Iteration: 271, Loss: 0.046312
# Iteration: 272, Loss: 0.046282
# Iteration: 273, Loss: 0.046215
# Iteration: 274, Loss: 0.046123
# Iteration: 275, Loss: 0.046027
# Iteration: 276, Loss: 0.045940
# Iteration: 277, Loss: 0.045874
# Iteration: 278, Loss: 0.045838
# Iteration: 279, Loss: 0.045813
# Iteration: 280, Loss: 0.045800
# Iteration: 281, Loss: 0.045789
# Iteration: 282, Loss: 0.045780
# Iteration: 283, Loss: 0.045770
# Iteration: 284, Loss: 0.045756
# Iteration: 285, Loss: 0.045736
# Iteration: 286, Loss: 0.045701
# Iteration: 287, Loss: 0.045647
# Iteration: 288, Loss: 0.045647
# Iteration: 289, Loss: 0.045610
# Iteration: 290, Loss: 0.045902
# Iteration: 291, Loss: 0.045568
# Iteration: 292, Loss: 0.045540
# Iteration: 293, Loss: 0.045521
# Iteration: 294, Loss: 0.045512
# Iteration: 295, Loss: 0.045499
# Iteration: 296, Loss: 0.045464
# Iteration: 297, Loss: 0.045438
# Iteration: 298, Loss: 0.045404
# Iteration: 299, Loss: 0.045332
# Iteration: 300, Loss: 0.045290
# Iteration: 301, Loss: 0.045241
# Iteration: 302, Loss: 0.045212
# Iteration: 303, Loss: 0.045186
# Iteration: 304, Loss: 0.045173
# Iteration: 305, Loss: 0.045159
# Iteration: 306, Loss: 0.045153
# Iteration: 307, Loss: 0.045145
# Iteration: 308, Loss: 0.045126
# Iteration: 309, Loss: 0.045110
# Iteration: 310, Loss: 0.045084
# Iteration: 311, Loss: 0.045056
# Iteration: 312, Loss: 0.045036
# Iteration: 313, Loss: 0.045030
# Iteration: 314, Loss: 0.045022
# Iteration: 315, Loss: 0.045018
# Iteration: 316, Loss: 0.045010
# Iteration: 317, Loss: 0.044999
# Iteration: 318, Loss: 0.044989
# Iteration: 319, Loss: 0.044982
# Iteration: 320, Loss: 0.044971
# Iteration: 321, Loss: 0.044949
# Iteration: 322, Loss: 0.045036
# Iteration: 323, Loss: 0.044915
# Iteration: 324, Loss: 0.044885
# Iteration: 325, Loss: 0.044874
# Iteration: 326, Loss: 0.044860
# Iteration: 327, Loss: 0.044852
# Iteration: 328, Loss: 0.044844
# Iteration: 329, Loss: 0.044832
# Iteration: 330, Loss: 0.044831
# Iteration: 331, Loss: 0.044826
# Iteration: 332, Loss: 0.044817
# Iteration: 333, Loss: 0.044813
# Iteration: 334, Loss: 0.044810
# Iteration: 335, Loss: 0.044808
# Iteration: 336, Loss: 0.044805
# Iteration: 337, Loss: 0.044803
# Iteration: 338, Loss: 0.044799
# Iteration: 339, Loss: 0.044794
# Iteration: 340, Loss: 0.044779
# Iteration: 341, Loss: 0.044762
# Iteration: 342, Loss: 0.044746
# Iteration: 343, Loss: 0.044719
# Iteration: 344, Loss: 0.044685
# Iteration: 345, Loss: 0.044660
# Iteration: 346, Loss: 0.044645
# Iteration: 347, Loss: 0.044609
# Iteration: 348, Loss: 0.044620
# Iteration: 349, Loss: 0.044601
# Iteration: 350, Loss: 0.044597
# Iteration: 351, Loss: 0.044582
# Iteration: 352, Loss: 0.044575
# Iteration: 353, Loss: 0.044565
# Iteration: 354, Loss: 0.044544
# Iteration: 355, Loss: 0.044533
# Iteration: 356, Loss: 0.044515
# Iteration: 357, Loss: 0.044504
# Iteration: 358, Loss: 0.044483
# Iteration: 359, Loss: 0.044459
# Iteration: 360, Loss: 0.044422
# Iteration: 361, Loss: 0.044394
# Iteration: 362, Loss: 0.044360
# Iteration: 363, Loss: 0.044305
# Iteration: 364, Loss: 0.044342
# Iteration: 365, Loss: 0.044258
# Iteration: 366, Loss: 0.044191
# Iteration: 367, Loss: 0.044251
# Iteration: 368, Loss: 0.044161
# Iteration: 369, Loss: 0.044149
# Iteration: 370, Loss: 0.044134
# Iteration: 371, Loss: 0.044126
# Iteration: 372, Loss: 0.044114
# Iteration: 373, Loss: 0.044084
# Iteration: 374, Loss: 0.044045
# Iteration: 375, Loss: 0.044162
# Iteration: 376, Loss: 0.044021
# Iteration: 377, Loss: 0.043998
# Iteration: 378, Loss: 0.043987
# Iteration: 379, Loss: 0.043975
# Iteration: 380, Loss: 0.043971
# Iteration: 381, Loss: 0.043964
# Iteration: 382, Loss: 0.043961
# Iteration: 383, Loss: 0.043958
# Iteration: 384, Loss: 0.043954
# Iteration: 385, Loss: 0.043950
# Iteration: 386, Loss: 0.043940
# Iteration: 387, Loss: 0.043924
# Iteration: 388, Loss: 0.043907
# Iteration: 389, Loss: 0.043893
# Iteration: 390, Loss: 0.043874
# Iteration: 391, Loss: 0.043878
# Iteration: 392, Loss: 0.043865
# Iteration: 393, Loss: 0.043847
# Iteration: 394, Loss: 0.043816
# Iteration: 395, Loss: 0.043790
# Iteration: 396, Loss: 0.043770
# Iteration: 397, Loss: 0.043757
# Iteration: 398, Loss: 0.043742
# Iteration: 399, Loss: 0.043707
# Iteration: 400, Loss: 0.043659
# Iteration: 401, Loss: 0.043587
# Iteration: 402, Loss: 0.043573
# Iteration: 403, Loss: 0.043539
# Iteration: 404, Loss: 0.043506
# Iteration: 405, Loss: 0.043627
# Iteration: 406, Loss: 0.043484
# Iteration: 407, Loss: 0.043456
# Iteration: 408, Loss: 0.043437
# Iteration: 409, Loss: 0.043419
# Iteration: 410, Loss: 0.043399
# Iteration: 411, Loss: 0.043385
# Iteration: 412, Loss: 0.043367
# Iteration: 413, Loss: 0.043351
# Iteration: 414, Loss: 0.043322
# Iteration: 415, Loss: 0.043301
# Iteration: 416, Loss: 0.043261
# Iteration: 417, Loss: 0.043196
# Iteration: 418, Loss: 0.043190
# Iteration: 419, Loss: 0.043158
# Iteration: 420, Loss: 0.043119
# Iteration: 421, Loss: 0.043058
# Iteration: 422, Loss: 0.042996
# Iteration: 423, Loss: 0.043002
# Iteration: 424, Loss: 0.042881
# Iteration: 425, Loss: 0.042746
# Iteration: 426, Loss: 0.042905
# Iteration: 427, Loss: 0.042561
# Iteration: 428, Loss: 0.043663
# Iteration: 429, Loss: 0.042505
# Iteration: 430, Loss: 0.043042
# Iteration: 431, Loss: 0.042412
# Iteration: 432, Loss: 0.042285
# Iteration: 433, Loss: 0.042209
# Iteration: 434, Loss: 0.042188
# Iteration: 435, Loss: 0.042232
# Iteration: 436, Loss: 0.042155
# Iteration: 437, Loss: 0.042129
# Iteration: 438, Loss: 0.042085
# Iteration: 439, Loss: 0.042027
# Iteration: 440, Loss: 0.041935
# Iteration: 441, Loss: 0.041817
# Iteration: 442, Loss: 0.041660
# Iteration: 443, Loss: 0.041677
# Iteration: 444, Loss: 0.041622
# Iteration: 445, Loss: 0.041581
# Iteration: 446, Loss: 0.041509
# Iteration: 447, Loss: 0.041379
# Iteration: 448, Loss: 0.041340
# Iteration: 449, Loss: 0.041297
# Iteration: 450, Loss: 0.041187
# Iteration: 451, Loss: 0.041126
# Iteration: 452, Loss: 0.041139
# Iteration: 453, Loss: 0.041044
# Iteration: 454, Loss: 0.041003
# Iteration: 455, Loss: 0.040935
# Iteration: 456, Loss: 0.040891
# Iteration: 457, Loss: 0.040834
# Iteration: 458, Loss: 0.040766
# Iteration: 459, Loss: 0.040735
# Iteration: 460, Loss: 0.040692
# Iteration: 461, Loss: 0.040631
# Iteration: 462, Loss: 0.040594
# Iteration: 463, Loss: 0.040534
# Iteration: 464, Loss: 0.040480
# Iteration: 465, Loss: 0.040543
# Iteration: 466, Loss: 0.040427
# Iteration: 467, Loss: 0.040349
# Iteration: 468, Loss: 0.040272
# Iteration: 469, Loss: 0.040215
# Iteration: 470, Loss: 0.040229
# Iteration: 471, Loss: 0.040189
# Iteration: 472, Loss: 0.040147
# Iteration: 473, Loss: 0.040094
# Iteration: 474, Loss: 0.040053
# Iteration: 475, Loss: 0.040022
# Iteration: 476, Loss: 0.039974
# Iteration: 477, Loss: 0.039958
# Iteration: 478, Loss: 0.039942
# Iteration: 479, Loss: 0.039928
# Iteration: 480, Loss: 0.039917
# Iteration: 481, Loss: 0.039889
# Iteration: 482, Loss: 0.039843
# Iteration: 483, Loss: 0.039855
# Iteration: 484, Loss: 0.039794
# Iteration: 485, Loss: 0.039665
# Iteration: 486, Loss: 0.039478
# Iteration: 487, Loss: 0.039414
# Iteration: 488, Loss: 0.039265
# Iteration: 489, Loss: 0.039193
# Iteration: 490, Loss: 0.039116
# Iteration: 491, Loss: 0.039140
# Iteration: 492, Loss: 0.039090
# Iteration: 493, Loss: 0.039066
# Iteration: 494, Loss: 0.039055
# Iteration: 495, Loss: 0.039035
# Iteration: 496, Loss: 0.038990
# Iteration: 497, Loss: 0.038948
# Iteration: 498, Loss: 0.038884
# Iteration: 499, Loss: 0.038835
# Iteration: 500, Loss: 0.038813
# Iteration: 501, Loss: 0.038790
# Iteration: 502, Loss: 0.038757
# Iteration: 503, Loss: 0.038738
# Iteration: 504, Loss: 0.038723
# Iteration: 505, Loss: 0.038704
# Iteration: 506, Loss: 0.038696
# Iteration: 507, Loss: 0.038687
# Iteration: 508, Loss: 0.038673
# Iteration: 509, Loss: 0.038657
# Iteration: 510, Loss: 0.038644
# Iteration: 511, Loss: 0.038632
# Iteration: 512, Loss: 0.038646
# Iteration: 513, Loss: 0.038616
# Iteration: 514, Loss: 0.038599
# Iteration: 515, Loss: 0.038561
# Iteration: 516, Loss: 0.038510
# Iteration: 517, Loss: 0.038441
# Iteration: 518, Loss: 0.038372
# Iteration: 519, Loss: 0.038324
# Iteration: 520, Loss: 0.038276
# Iteration: 521, Loss: 0.038221
# Iteration: 522, Loss: 0.038156
# Iteration: 523, Loss: 0.038118
# Iteration: 524, Loss: 0.038098
# Iteration: 525, Loss: 0.038090
# Iteration: 526, Loss: 0.038078
# Iteration: 527, Loss: 0.038055
# Iteration: 528, Loss: 0.038017
# Iteration: 529, Loss: 0.037974
# Iteration: 530, Loss: 0.037911
# Iteration: 531, Loss: 0.037832
# Iteration: 532, Loss: 0.037772
# Iteration: 533, Loss: 0.037789
# Iteration: 534, Loss: 0.037755
# Iteration: 535, Loss: 0.037743
# Iteration: 536, Loss: 0.037717
# Iteration: 537, Loss: 0.037744
# Iteration: 538, Loss: 0.037711
# Iteration: 539, Loss: 0.037697
# Iteration: 540, Loss: 0.037662
# Iteration: 541, Loss: 0.037596
# Iteration: 542, Loss: 0.037532
# Iteration: 543, Loss: 0.037376
# Iteration: 544, Loss: 0.037292
# Iteration: 545, Loss: 0.037552
# Iteration: 546, Loss: 0.037200
# Iteration: 547, Loss: 0.037190
# Iteration: 548, Loss: 0.037102
# Iteration: 549, Loss: 0.037031
# Iteration: 550, Loss: 0.036957
# Iteration: 551, Loss: 0.036904
# Iteration: 552, Loss: 0.036849
# Iteration: 553, Loss: 0.036815
# Iteration: 554, Loss: 0.036783
# Iteration: 555, Loss: 0.036734
# Iteration: 556, Loss: 0.036674
# Iteration: 557, Loss: 0.036654
# Iteration: 558, Loss: 0.036611
# Iteration: 559, Loss: 0.036595
# Iteration: 560, Loss: 0.036568
# Iteration: 561, Loss: 0.036521
# Iteration: 562, Loss: 0.036472
# Iteration: 563, Loss: 0.036411
# Iteration: 564, Loss: 0.036372
# Iteration: 565, Loss: 0.036325
# Iteration: 566, Loss: 0.036263
# Iteration: 567, Loss: 0.036170
# Iteration: 568, Loss: 0.036008
# Iteration: 569, Loss: 0.035883
# Iteration: 570, Loss: 0.035805
# Iteration: 571, Loss: 0.035668
# Iteration: 572, Loss: 0.035556
# Iteration: 573, Loss: 0.035527
# Iteration: 574, Loss: 0.035546
# Iteration: 575, Loss: 0.035442
# Iteration: 576, Loss: 0.035470
# Iteration: 577, Loss: 0.035405
# Iteration: 578, Loss: 0.035388
# Iteration: 579, Loss: 0.035375
# Iteration: 580, Loss: 0.035370
# Iteration: 581, Loss: 0.035368
# Iteration: 582, Loss: 0.035363
# Iteration: 583, Loss: 0.035356
# Iteration: 584, Loss: 0.035350
# Iteration: 585, Loss: 0.035341
# Iteration: 586, Loss: 0.035333
# Iteration: 587, Loss: 0.035328
# Iteration: 588, Loss: 0.035321
# Iteration: 589, Loss: 0.035309
# Iteration: 590, Loss: 0.035289
# Iteration: 591, Loss: 0.035259
# Iteration: 592, Loss: 0.035226
# Iteration: 593, Loss: 0.035202
# Iteration: 594, Loss: 0.035188
# Iteration: 595, Loss: 0.035178
# Iteration: 596, Loss: 0.035169
# Iteration: 597, Loss: 0.035159
# Iteration: 598, Loss: 0.035149
# Iteration: 599, Loss: 0.035141
# Iteration: 600, Loss: 0.035129
# Iteration: 601, Loss: 0.035128
# Iteration: 602, Loss: 0.035125
# Iteration: 603, Loss: 0.035121
# Iteration: 604, Loss: 0.035117
# Iteration: 605, Loss: 0.035114
# Iteration: 606, Loss: 0.035108
# Iteration: 607, Loss: 0.035099
# Iteration: 608, Loss: 0.035081
# Iteration: 609, Loss: 0.035057
# Iteration: 610, Loss: 0.035030
# Iteration: 611, Loss: 0.035021
# Iteration: 612, Loss: 0.035016
# Iteration: 613, Loss: 0.035014
# Iteration: 614, Loss: 0.035014
# Iteration: 615, Loss: 0.035012
# Iteration: 616, Loss: 0.035009
# Iteration: 617, Loss: 0.035006
# Iteration: 618, Loss: 0.035003
# Iteration: 619, Loss: 0.034998
# Iteration: 620, Loss: 0.034991
# Iteration: 621, Loss: 0.034984
# Iteration: 622, Loss: 0.034970
# Iteration: 623, Loss: 0.034960
# Iteration: 624, Loss: 0.034954
# Iteration: 625, Loss: 0.034969
# Iteration: 626, Loss: 0.034952
# Iteration: 627, Loss: 0.034947
# Iteration: 628, Loss: 0.034942
# Iteration: 629, Loss: 0.034935
# Iteration: 630, Loss: 0.034925
# Iteration: 631, Loss: 0.034914
# Iteration: 632, Loss: 0.034899
# Iteration: 633, Loss: 0.034921
# Iteration: 634, Loss: 0.034882
# Iteration: 635, Loss: 0.034873
# Iteration: 636, Loss: 0.034839
# Iteration: 637, Loss: 0.034818
# Iteration: 638, Loss: 0.034799
# Iteration: 639, Loss: 0.034776
# Iteration: 640, Loss: 0.034766
# Iteration: 641, Loss: 0.034748
# Iteration: 642, Loss: 0.034725
# Iteration: 643, Loss: 0.034712
# Iteration: 644, Loss: 0.034690
# Iteration: 645, Loss: 0.034667
# Iteration: 646, Loss: 0.034641
# Iteration: 647, Loss: 0.034618
# Iteration: 648, Loss: 0.034637
# Iteration: 649, Loss: 0.034608
# Iteration: 650, Loss: 0.034600
# Iteration: 651, Loss: 0.034650
# Iteration: 652, Loss: 0.034595
# Iteration: 653, Loss: 0.034589
# Iteration: 654, Loss: 0.034585
# Iteration: 655, Loss: 0.034576
# Iteration: 656, Loss: 0.034571
# Iteration: 657, Loss: 0.034569
# Iteration: 658, Loss: 0.034566
# Iteration: 659, Loss: 0.034564
# Iteration: 660, Loss: 0.034562
# Iteration: 661, Loss: 0.034559
# Iteration: 662, Loss: 0.034555
# Iteration: 663, Loss: 0.034542
# Iteration: 664, Loss: 0.034534
# Iteration: 665, Loss: 0.034518
# Iteration: 666, Loss: 0.034500
# Iteration: 667, Loss: 0.034467
# Iteration: 668, Loss: 0.034544
# Iteration: 669, Loss: 0.034446
# Iteration: 670, Loss: 0.034390
# Iteration: 671, Loss: 0.034352
# Iteration: 672, Loss: 0.034372
# Iteration: 673, Loss: 0.034300
# Iteration: 674, Loss: 0.034286
# Iteration: 675, Loss: 0.034246
# Iteration: 676, Loss: 0.034235
# Iteration: 677, Loss: 0.034225
# Iteration: 678, Loss: 0.034215
# Iteration: 679, Loss: 0.034206
# Iteration: 680, Loss: 0.034200
# Iteration: 681, Loss: 0.034193
# Iteration: 682, Loss: 0.034186
# Iteration: 683, Loss: 0.034184
# Iteration: 684, Loss: 0.034183
# Iteration: 685, Loss: 0.034181
# Iteration: 686, Loss: 0.034179
# Iteration: 687, Loss: 0.034175
# Iteration: 688, Loss: 0.034174
# Iteration: 689, Loss: 0.034172
# Iteration: 690, Loss: 0.034167
# Iteration: 691, Loss: 0.034159
# Iteration: 692, Loss: 0.034150
# Iteration: 693, Loss: 0.034131
# Iteration: 694, Loss: 0.034114
# Iteration: 695, Loss: 0.034089
# Iteration: 696, Loss: 0.034081
# Iteration: 697, Loss: 0.034070
# Iteration: 698, Loss: 0.034063
# Iteration: 699, Loss: 0.034049
# Iteration: 700, Loss: 0.034036
# Iteration: 701, Loss: 0.034027
# Iteration: 702, Loss: 0.034022
# Iteration: 703, Loss: 0.034018
# Iteration: 704, Loss: 0.034015
# Iteration: 705, Loss: 0.034020
# Iteration: 706, Loss: 0.034013
# Iteration: 707, Loss: 0.034009
# Iteration: 708, Loss: 0.034006
# Iteration: 709, Loss: 0.034004
# Iteration: 710, Loss: 0.034001
# Iteration: 711, Loss: 0.033997
# Iteration: 712, Loss: 0.033991
# Iteration: 713, Loss: 0.033978
# Iteration: 714, Loss: 0.033963
# Iteration: 715, Loss: 0.033938
# Iteration: 716, Loss: 0.033909
# Iteration: 717, Loss: 0.033990
# Iteration: 718, Loss: 0.033896
# Iteration: 719, Loss: 0.033871
# Iteration: 720, Loss: 0.033839
# Iteration: 721, Loss: 0.033824
# Iteration: 722, Loss: 0.033793
# Iteration: 723, Loss: 0.033792
# Iteration: 724, Loss: 0.033776
# Iteration: 725, Loss: 0.033817
# Iteration: 726, Loss: 0.033751
# Iteration: 727, Loss: 0.033736
# Iteration: 728, Loss: 0.033693
# Iteration: 729, Loss: 0.033678
# Iteration: 730, Loss: 0.033661
# Iteration: 731, Loss: 0.033629
# Iteration: 732, Loss: 0.033609
# Iteration: 733, Loss: 0.033622
# Iteration: 734, Loss: 0.033594
# Iteration: 735, Loss: 0.033574
# Iteration: 736, Loss: 0.033562
# Iteration: 737, Loss: 0.033551
# Iteration: 738, Loss: 0.033541
# Iteration: 739, Loss: 0.033532
# Iteration: 740, Loss: 0.033523
# Iteration: 741, Loss: 0.033515
# Iteration: 742, Loss: 0.033505
# Iteration: 743, Loss: 0.033498
# Iteration: 744, Loss: 0.033491
# Iteration: 745, Loss: 0.033476
# Iteration: 746, Loss: 0.033477
# Iteration: 747, Loss: 0.033465
# Iteration: 748, Loss: 0.033453
# Iteration: 749, Loss: 0.033438
# Iteration: 750, Loss: 0.033431
# Iteration: 751, Loss: 0.033422
# Iteration: 752, Loss: 0.033406
# Iteration: 753, Loss: 0.033394
# Iteration: 754, Loss: 0.033383
# Iteration: 755, Loss: 0.033381
# Iteration: 756, Loss: 0.033371
# Iteration: 757, Loss: 0.033360
# Iteration: 758, Loss: 0.033355
# Iteration: 759, Loss: 0.033348
# Iteration: 760, Loss: 0.033344
# Iteration: 761, Loss: 0.033338
# Iteration: 762, Loss: 0.033336
# Iteration: 763, Loss: 0.033333
# Iteration: 764, Loss: 0.033330
# Iteration: 765, Loss: 0.033327
# Iteration: 766, Loss: 0.033323
# Iteration: 767, Loss: 0.033317
# Iteration: 768, Loss: 0.033310
# Iteration: 769, Loss: 0.033300
# Iteration: 770, Loss: 0.033293
# Iteration: 771, Loss: 0.033284
# Iteration: 772, Loss: 0.033281
# Iteration: 773, Loss: 0.033269
# Iteration: 774, Loss: 0.033244
# Iteration: 775, Loss: 0.033243
# Iteration: 776, Loss: 0.033218
# Iteration: 777, Loss: 0.033188
# Iteration: 778, Loss: 0.033151
# Iteration: 779, Loss: 0.033176
# Iteration: 780, Loss: 0.033135
# Iteration: 781, Loss: 0.033143
# Iteration: 782, Loss: 0.033122
# Iteration: 783, Loss: 0.033120
# Iteration: 784, Loss: 0.033109
# Iteration: 785, Loss: 0.033084
# Iteration: 786, Loss: 0.033082
# Iteration: 787, Loss: 0.033073
# Iteration: 788, Loss: 0.033066
# Iteration: 789, Loss: 0.033060
# Iteration: 790, Loss: 0.033046
# Iteration: 791, Loss: 0.033042
# Iteration: 792, Loss: 0.033031
# Iteration: 793, Loss: 0.033024
# Iteration: 794, Loss: 0.033014
# Iteration: 795, Loss: 0.032989
# Iteration: 796, Loss: 0.032980
# Iteration: 797, Loss: 0.032981
# Iteration: 798, Loss: 0.032974
# Iteration: 799, Loss: 0.032967
# Iteration: 800, Loss: 0.032959
# Iteration: 801, Loss: 0.032954
# Iteration: 802, Loss: 0.032943
# Iteration: 803, Loss: 0.032933
# Iteration: 804, Loss: 0.032923
# Iteration: 805, Loss: 0.032911
# Iteration: 806, Loss: 0.032908
# Iteration: 807, Loss: 0.032899
# Iteration: 808, Loss: 0.032905
# Iteration: 809, Loss: 0.032894
# Iteration: 810, Loss: 0.032888
# Iteration: 811, Loss: 0.032889
# Iteration: 812, Loss: 0.032885
# Iteration: 813, Loss: 0.032882
# Iteration: 814, Loss: 0.032879
# Iteration: 815, Loss: 0.032878
# Iteration: 816, Loss: 0.032877
# Iteration: 817, Loss: 0.032876
# Iteration: 818, Loss: 0.032875
# Iteration: 819, Loss: 0.032871
# Iteration: 820, Loss: 0.032868
# Iteration: 821, Loss: 0.032865
# Iteration: 822, Loss: 0.032862
# Iteration: 823, Loss: 0.032859
# Iteration: 824, Loss: 0.032854
# Iteration: 825, Loss: 0.032850
# Iteration: 826, Loss: 0.032842
# Iteration: 827, Loss: 0.032836
# Iteration: 828, Loss: 0.032833
# Iteration: 829, Loss: 0.032831
# Iteration: 830, Loss: 0.032827
# Iteration: 831, Loss: 0.032818
# Iteration: 832, Loss: 0.032804
# Iteration: 833, Loss: 0.032779
# Iteration: 834, Loss: 0.032768
# Iteration: 835, Loss: 0.032758
# Iteration: 836, Loss: 0.032737
# Iteration: 837, Loss: 0.032720
# Iteration: 838, Loss: 0.032707
# Iteration: 839, Loss: 0.032700
# Iteration: 840, Loss: 0.032689
# Iteration: 841, Loss: 0.032684
# Iteration: 842, Loss: 0.032675
# Iteration: 843, Loss: 0.032664
# Iteration: 844, Loss: 0.032664
# Iteration: 845, Loss: 0.032658
# Iteration: 846, Loss: 0.032673
# Iteration: 847, Loss: 0.032653
# Iteration: 848, Loss: 0.032647
# Iteration: 849, Loss: 0.032641
# Iteration: 850, Loss: 0.032637
# Iteration: 851, Loss: 0.032633
# Iteration: 852, Loss: 0.032627
# Iteration: 853, Loss: 0.032621
# Iteration: 854, Loss: 0.032615
# Iteration: 855, Loss: 0.032607
# Iteration: 856, Loss: 0.032598
# Iteration: 857, Loss: 0.032583
# Iteration: 858, Loss: 0.032558
# Iteration: 859, Loss: 0.032528
# Iteration: 860, Loss: 0.033046
# Iteration: 861, Loss: 0.032501
# Iteration: 862, Loss: 0.032450
# Iteration: 863, Loss: 0.032430
# Iteration: 864, Loss: 0.032411
# Iteration: 865, Loss: 0.032397
# Iteration: 866, Loss: 0.032392
# Iteration: 867, Loss: 0.032387
# Iteration: 868, Loss: 0.032385
# Iteration: 869, Loss: 0.032381
# Iteration: 870, Loss: 0.032377
# Iteration: 871, Loss: 0.032375
# Iteration: 872, Loss: 0.032379
# Iteration: 873, Loss: 0.032373
# Iteration: 874, Loss: 0.032369
# Iteration: 875, Loss: 0.032364
# Iteration: 876, Loss: 0.032350
# Iteration: 877, Loss: 0.032339
# Iteration: 878, Loss: 0.032332
# Iteration: 879, Loss: 0.032324
# Iteration: 880, Loss: 0.032319
# Iteration: 881, Loss: 0.032311
# Iteration: 882, Loss: 0.032302
# Iteration: 883, Loss: 0.032291
# Iteration: 884, Loss: 0.032277
# Iteration: 885, Loss: 0.032269
# Iteration: 886, Loss: 0.032257
# Iteration: 887, Loss: 0.032253
# Iteration: 888, Loss: 0.032250
# Iteration: 889, Loss: 0.032246
# Iteration: 890, Loss: 0.032241
# Iteration: 891, Loss: 0.032272
# Iteration: 892, Loss: 0.032239
# Iteration: 893, Loss: 0.032236
# Iteration: 894, Loss: 0.032233
# Iteration: 895, Loss: 0.032230
# Iteration: 896, Loss: 0.032282
# Iteration: 897, Loss: 0.032229
# Iteration: 898, Loss: 0.032227
# Iteration: 899, Loss: 0.032223
# Iteration: 900, Loss: 0.032221
# Iteration: 901, Loss: 0.032219
# Iteration: 902, Loss: 0.032217
# Iteration: 903, Loss: 0.032214
# Iteration: 904, Loss: 0.032217
# Iteration: 905, Loss: 0.032212
# Iteration: 906, Loss: 0.032214
# Iteration: 907, Loss: 0.032209
# Iteration: 908, Loss: 0.032201
# Iteration: 909, Loss: 0.032185
# Iteration: 910, Loss: 0.032169
# Iteration: 911, Loss: 0.032164
# Iteration: 912, Loss: 0.032159
# Iteration: 913, Loss: 0.032153
# Iteration: 914, Loss: 0.032149
# Iteration: 915, Loss: 0.032146
# Iteration: 916, Loss: 0.032143
# Iteration: 917, Loss: 0.032143
# Iteration: 918, Loss: 0.032141
# Iteration: 919, Loss: 0.032140
# Iteration: 920, Loss: 0.032139
# Iteration: 921, Loss: 0.032138
# Iteration: 922, Loss: 0.032150
# Iteration: 923, Loss: 0.032138
# Iteration: 924, Loss: 0.032152
# Iteration: 925, Loss: 0.032138
# Iteration: 926, Loss: 0.032137
# Iteration: 927, Loss: 0.032136
# Iteration: 928, Loss: 0.032134
# Iteration: 929, Loss: 0.032132
# Iteration: 930, Loss: 0.032129
# Iteration: 931, Loss: 0.032126
# Iteration: 932, Loss: 0.032122
# Iteration: 933, Loss: 0.032117
# Iteration: 934, Loss: 0.032109
# Iteration: 935, Loss: 0.032099
# Iteration: 936, Loss: 0.032090
# Iteration: 937, Loss: 0.032100
# Iteration: 938, Loss: 0.032084
# Iteration: 939, Loss: 0.032078
# Iteration: 940, Loss: 0.032073
# Iteration: 941, Loss: 0.032067
# Iteration: 942, Loss: 0.032062
# Iteration: 943, Loss: 0.032086
# Iteration: 944, Loss: 0.032058
# Iteration: 945, Loss: 0.032053
# Iteration: 946, Loss: 0.032049
# Iteration: 947, Loss: 0.032047
# Iteration: 948, Loss: 0.032044
# Iteration: 949, Loss: 0.032040
# Iteration: 950, Loss: 0.032035
# Iteration: 951, Loss: 0.032034
# Iteration: 952, Loss: 0.032032
# Iteration: 953, Loss: 0.032031
# Iteration: 954, Loss: 0.032030
# Iteration: 955, Loss: 0.032029
# Iteration: 956, Loss: 0.032027
# Iteration: 957, Loss: 0.032023
# Iteration: 958, Loss: 0.032020
# Iteration: 959, Loss: 0.032018
# Iteration: 960, Loss: 0.032014
# Iteration: 961, Loss: 0.032009
# Iteration: 962, Loss: 0.032002
# Iteration: 963, Loss: 0.031999
# Iteration: 964, Loss: 0.031995
# Iteration: 965, Loss: 0.031990
# Iteration: 966, Loss: 0.031986
# Iteration: 967, Loss: 0.031978
# Iteration: 968, Loss: 0.031978
# Iteration: 969, Loss: 0.031973
# Iteration: 970, Loss: 0.031967
# Iteration: 971, Loss: 0.031979
# Iteration: 972, Loss: 0.031960
# Iteration: 973, Loss: 0.031944
# Iteration: 974, Loss: 0.031928
# Iteration: 975, Loss: 0.031912
# Iteration: 976, Loss: 0.031900
# Iteration: 977, Loss: 0.031889
# Iteration: 978, Loss: 0.031881
# Iteration: 979, Loss: 0.031877
# Iteration: 980, Loss: 0.031882
# Iteration: 981, Loss: 0.031875
# Iteration: 982, Loss: 0.031873
# Iteration: 983, Loss: 0.031870
# Iteration: 984, Loss: 0.031870
# Iteration: 985, Loss: 0.031869
# Iteration: 986, Loss: 0.031867
# Iteration: 987, Loss: 0.031866
# Iteration: 988, Loss: 0.031863
# Iteration: 989, Loss: 0.031860
# Iteration: 990, Loss: 0.031857
# Iteration: 991, Loss: 0.031856
# Iteration: 992, Loss: 0.031854
# Iteration: 993, Loss: 0.031854
# Iteration: 994, Loss: 0.031853
# Iteration: 995, Loss: 0.031852
# Iteration: 996, Loss: 0.031851
# Iteration: 997, Loss: 0.031849
# Iteration: 998, Loss: 0.031852
# Iteration: 999, Loss: 0.031849
# Iteration: 1000, Loss: 0.031847
# Iteration: 1001, Loss: 0.031847
# Iteration: 1002, Loss: 0.031846
# Iteration: 1003, Loss: 0.031845
# Iteration: 1004, Loss: 0.031844
# Iteration: 1005, Loss: 0.031843
# Iteration: 1006, Loss: 0.031844
# Iteration: 1007, Loss: 0.031843
# Iteration: 1008, Loss: 0.031848
# Iteration: 1009, Loss: 0.031842
# Iteration: 1010, Loss: 0.031841
# Iteration: 1011, Loss: 0.031839
# Iteration: 1012, Loss: 0.031837
# Iteration: 1013, Loss: 0.031835
# Iteration: 1014, Loss: 0.031833
# Iteration: 1015, Loss: 0.031830
# Iteration: 1016, Loss: 0.031828
# Iteration: 1017, Loss: 0.031827
# Iteration: 1018, Loss: 0.031823
# Iteration: 1019, Loss: 0.031819
# Iteration: 1020, Loss: 0.031817
# Iteration: 1021, Loss: 0.031814
# Iteration: 1022, Loss: 0.031811
# Iteration: 1023, Loss: 0.031808
# Iteration: 1024, Loss: 0.031798
# Iteration: 1025, Loss: 0.031788
# Iteration: 1026, Loss: 0.031778
# Iteration: 1027, Loss: 0.031778
# Iteration: 1028, Loss: 0.031773
# Iteration: 1029, Loss: 0.031770
# Iteration: 1030, Loss: 0.031764
# Iteration: 1031, Loss: 0.031757
# Iteration: 1032, Loss: 0.031750
# Iteration: 1033, Loss: 0.031745
# Iteration: 1034, Loss: 0.031822
# Iteration: 1035, Loss: 0.031743
# Iteration: 1036, Loss: 0.031736
# Iteration: 1037, Loss: 0.031726
# Iteration: 1038, Loss: 0.031710
# Iteration: 1039, Loss: 0.031692
# Iteration: 1040, Loss: 0.031678
# Iteration: 1041, Loss: 0.031668
# Iteration: 1042, Loss: 0.031661
# Iteration: 1043, Loss: 0.031674
# Iteration: 1044, Loss: 0.031655
# Iteration: 1045, Loss: 0.031643
# Iteration: 1046, Loss: 0.031633
# Iteration: 1047, Loss: 0.031624
# Iteration: 1048, Loss: 0.031620
# Iteration: 1049, Loss: 0.031623
# Iteration: 1050, Loss: 0.031618
# Iteration: 1051, Loss: 0.031615
# Iteration: 1052, Loss: 0.031614
# Iteration: 1053, Loss: 0.031613
# Iteration: 1054, Loss: 0.031610
# Iteration: 1055, Loss: 0.031608
# Iteration: 1056, Loss: 0.031605
# Iteration: 1057, Loss: 0.031602
# Iteration: 1058, Loss: 0.031601
# Iteration: 1059, Loss: 0.031633
# Iteration: 1060, Loss: 0.031600
# Iteration: 1061, Loss: 0.031598
# Iteration: 1062, Loss: 0.031594
# Iteration: 1063, Loss: 0.031592
# Iteration: 1064, Loss: 0.031589
# Iteration: 1065, Loss: 0.031586
# Iteration: 1066, Loss: 0.031583
# Iteration: 1067, Loss: 0.031576
# Iteration: 1068, Loss: 0.031576
# Iteration: 1069, Loss: 0.031573
# Iteration: 1070, Loss: 0.031570
# Iteration: 1071, Loss: 0.031564
# Iteration: 1072, Loss: 0.031570
# Iteration: 1073, Loss: 0.031561
# Iteration: 1074, Loss: 0.031559
# Iteration: 1075, Loss: 0.031555
# Iteration: 1076, Loss: 0.031553
# Iteration: 1077, Loss: 0.031552
# Iteration: 1078, Loss: 0.031550
# Iteration: 1079, Loss: 0.031549
# Iteration: 1080, Loss: 0.031548
# Iteration: 1081, Loss: 0.031547
# Iteration: 1082, Loss: 0.031548
# Iteration: 1083, Loss: 0.031546
# Iteration: 1084, Loss: 0.031545
# Iteration: 1085, Loss: 0.031546
# Iteration: 1086, Loss: 0.031544
# Iteration: 1087, Loss: 0.031546
# Iteration: 1088, Loss: 0.031543
# Iteration: 1089, Loss: 0.031541
# Iteration: 1090, Loss: 0.031539
# Iteration: 1091, Loss: 0.031537
# Iteration: 1092, Loss: 0.031537
# Iteration: 1093, Loss: 0.031536
# Iteration: 1094, Loss: 0.031536
# Iteration: 1095, Loss: 0.031535
# Iteration: 1096, Loss: 0.031538
# Iteration: 1097, Loss: 0.031532
# Iteration: 1098, Loss: 0.031528
# Iteration: 1099, Loss: 0.031526
# Iteration: 1100, Loss: 0.031525
# Iteration: 1101, Loss: 0.031523
# Iteration: 1102, Loss: 0.031522
# Iteration: 1103, Loss: 0.031521
# Iteration: 1104, Loss: 0.031518
# Iteration: 1105, Loss: 0.031514
# Iteration: 1106, Loss: 0.031509
# Iteration: 1107, Loss: 0.031506
# Iteration: 1108, Loss: 0.031501
# Iteration: 1109, Loss: 0.031496
# Iteration: 1110, Loss: 0.031492
# Iteration: 1111, Loss: 0.031488
# Iteration: 1112, Loss: 0.031484
# Iteration: 1113, Loss: 0.031479
# Iteration: 1114, Loss: 0.031474
# Iteration: 1115, Loss: 0.031468
# Iteration: 1116, Loss: 0.031470
# Iteration: 1117, Loss: 0.031462
# Iteration: 1118, Loss: 0.031457
# Iteration: 1119, Loss: 0.031452
# Iteration: 1120, Loss: 0.031450
# Iteration: 1121, Loss: 0.031443
# Iteration: 1122, Loss: 0.031439
# Iteration: 1123, Loss: 0.031434
# Iteration: 1124, Loss: 0.031433
# Iteration: 1125, Loss: 0.031429
# Iteration: 1126, Loss: 0.031427
# Iteration: 1127, Loss: 0.031423
# Iteration: 1128, Loss: 0.031413
# Iteration: 1129, Loss: 0.031404
# Iteration: 1130, Loss: 0.031397
# Iteration: 1131, Loss: 0.031389
# Iteration: 1132, Loss: 0.031383
# Iteration: 1133, Loss: 0.031377
# Iteration: 1134, Loss: 0.031376
# Iteration: 1135, Loss: 0.031373
# Iteration: 1136, Loss: 0.031370
# Iteration: 1137, Loss: 0.031368
# Iteration: 1138, Loss: 0.031362
# Iteration: 1139, Loss: 0.031999
# Iteration: 1140, Loss: 0.031359
# Iteration: 1141, Loss: 0.031352
# Iteration: 1142, Loss: 0.031340
# Iteration: 1143, Loss: 0.031340
# Iteration: 1144, Loss: 0.031333
# Iteration: 1145, Loss: 0.031322
# Iteration: 1146, Loss: 0.031313
# Iteration: 1147, Loss: 0.031307
# Iteration: 1148, Loss: 0.031304
# Iteration: 1149, Loss: 0.031299
# Iteration: 1150, Loss: 0.031292
# Iteration: 1151, Loss: 0.031288
# Iteration: 1152, Loss: 0.031285
# Iteration: 1153, Loss: 0.031283
# Iteration: 1154, Loss: 0.031281
# Iteration: 1155, Loss: 0.031278
# Iteration: 1156, Loss: 0.031274
# Iteration: 1157, Loss: 0.031266
# Iteration: 1158, Loss: 0.031254
# Iteration: 1159, Loss: 0.031242
# Iteration: 1160, Loss: 0.031234
# Iteration: 1161, Loss: 0.031225
# Iteration: 1162, Loss: 0.031213
# Iteration: 1163, Loss: 0.031207
# Iteration: 1164, Loss: 0.031198
# Iteration: 1165, Loss: 0.031186
# Iteration: 1166, Loss: 0.031185
# Iteration: 1167, Loss: 0.031179
# Iteration: 1168, Loss: 0.031168
# Iteration: 1169, Loss: 0.031162
# Iteration: 1170, Loss: 0.031158
# Iteration: 1171, Loss: 0.031156
# Iteration: 1172, Loss: 0.031155
# Iteration: 1173, Loss: 0.031150
# Iteration: 1174, Loss: 0.031146
# Iteration: 1175, Loss: 0.031130
# Iteration: 1176, Loss: 0.031166
# Iteration: 1177, Loss: 0.031124
# Iteration: 1178, Loss: 0.031115
# Iteration: 1179, Loss: 0.031109
# Iteration: 1180, Loss: 0.031103
# Iteration: 1181, Loss: 0.031098
# Iteration: 1182, Loss: 0.031092
# Iteration: 1183, Loss: 0.031101
# Iteration: 1184, Loss: 0.031089
# Iteration: 1185, Loss: 0.031084
# Iteration: 1186, Loss: 0.031078
# Iteration: 1187, Loss: 0.031074
# Iteration: 1188, Loss: 0.031072
# Iteration: 1189, Loss: 0.031071
# Iteration: 1190, Loss: 0.031070
# Iteration: 1191, Loss: 0.031069
# Iteration: 1192, Loss: 0.031072
# Iteration: 1193, Loss: 0.031068
# Iteration: 1194, Loss: 0.031066
# Iteration: 1195, Loss: 0.031063
# Iteration: 1196, Loss: 0.031061
# Iteration: 1197, Loss: 0.031057
# Iteration: 1198, Loss: 0.031061
# Iteration: 1199, Loss: 0.031055
# Iteration: 1200, Loss: 0.031049
# Iteration: 1201, Loss: 0.031043
# Iteration: 1202, Loss: 0.031038
# Iteration: 1203, Loss: 0.031031
# Iteration: 1204, Loss: 0.031024
# Iteration: 1205, Loss: 0.031015
# Iteration: 1206, Loss: 0.031011
# Iteration: 1207, Loss: 0.031007
# Iteration: 1208, Loss: 0.031003
# Iteration: 1209, Loss: 0.031000
# Iteration: 1210, Loss: 0.030996
# Iteration: 1211, Loss: 0.030990
# Iteration: 1212, Loss: 0.031013
# Iteration: 1213, Loss: 0.030987
# Iteration: 1214, Loss: 0.030979
# Iteration: 1215, Loss: 0.030967
# Iteration: 1216, Loss: 0.030957
# Iteration: 1217, Loss: 0.030944
# Iteration: 1218, Loss: 0.030931
# Iteration: 1219, Loss: 0.030917
# Iteration: 1220, Loss: 0.030902
# Iteration: 1221, Loss: 0.030885
# Iteration: 1222, Loss: 0.030872
# Iteration: 1223, Loss: 0.030856
# Iteration: 1224, Loss: 0.030842
# Iteration: 1225, Loss: 0.030833
# Iteration: 1226, Loss: 0.030834
# Iteration: 1227, Loss: 0.030829
# Iteration: 1228, Loss: 0.030824
# Iteration: 1229, Loss: 0.030820
# Iteration: 1230, Loss: 0.030815
# Iteration: 1231, Loss: 0.030811
# Iteration: 1232, Loss: 0.030804
# Iteration: 1233, Loss: 0.030799
# Iteration: 1234, Loss: 0.030793
# Iteration: 1235, Loss: 0.030787
# Iteration: 1236, Loss: 0.030789
# Iteration: 1237, Loss: 0.030785
# Iteration: 1238, Loss: 0.030782
# Iteration: 1239, Loss: 0.030794
# Iteration: 1240, Loss: 0.030780
# Iteration: 1241, Loss: 0.030777
# Iteration: 1242, Loss: 0.030775
# Iteration: 1243, Loss: 0.030775
# Iteration: 1244, Loss: 0.030774
# Iteration: 1245, Loss: 0.030773
# Iteration: 1246, Loss: 0.030772
# Iteration: 1247, Loss: 0.030770
# Iteration: 1248, Loss: 0.030763
# Iteration: 1249, Loss: 0.032976
# Iteration: 1250, Loss: 0.030774
# Iteration: 1251, Loss: 0.030760
# Iteration: 1252, Loss: 0.030753
# Iteration: 1253, Loss: 0.030745
# Iteration: 1254, Loss: 0.030742
# Iteration: 1255, Loss: 0.030734
# Iteration: 1256, Loss: 0.030730
# Iteration: 1257, Loss: 0.030726
# Iteration: 1258, Loss: 0.030720
# Iteration: 1259, Loss: 0.030714
# Iteration: 1260, Loss: 0.030711
# Iteration: 1261, Loss: 0.030709
# Iteration: 1262, Loss: 0.030705
# Iteration: 1263, Loss: 0.030702
# Iteration: 1264, Loss: 0.030697
# Iteration: 1265, Loss: 0.030693
# Iteration: 1266, Loss: 0.030688
# Iteration: 1267, Loss: 0.030682
# Iteration: 1268, Loss: 0.030673
# Iteration: 1269, Loss: 0.030667
# Iteration: 1270, Loss: 0.030670
# Iteration: 1271, Loss: 0.030660
# Iteration: 1272, Loss: 0.030654
# Iteration: 1273, Loss: 0.030641
# Iteration: 1274, Loss: 0.030636
# Iteration: 1275, Loss: 0.030629
# Iteration: 1276, Loss: 0.030625
# Iteration: 1277, Loss: 0.030623
# Iteration: 1278, Loss: 0.030622
# Iteration: 1279, Loss: 0.030621
# Iteration: 1280, Loss: 0.030618
# Iteration: 1281, Loss: 0.030616
# Iteration: 1282, Loss: 0.030614
# Iteration: 1283, Loss: 0.030613
# Iteration: 1284, Loss: 0.030611
# Iteration: 1285, Loss: 0.030608
# Iteration: 1286, Loss: 0.030605
# Iteration: 1287, Loss: 0.030601
# Iteration: 1288, Loss: 0.030599
# Iteration: 1289, Loss: 0.030597
# Iteration: 1290, Loss: 0.030596
# Iteration: 1291, Loss: 0.030595
# Iteration: 1292, Loss: 0.030592
# Iteration: 1293, Loss: 0.030590
# Iteration: 1294, Loss: 0.030586
# Iteration: 1295, Loss: 0.030583
# Iteration: 1296, Loss: 0.030581
# Iteration: 1297, Loss: 0.030577
# Iteration: 1298, Loss: 0.030571
# Iteration: 1299, Loss: 0.030561
# Iteration: 1300, Loss: 0.030552
# Iteration: 1301, Loss: 0.030545
# Iteration: 1302, Loss: 0.030535
# Iteration: 1303, Loss: 0.030525
# Iteration: 1304, Loss: 0.030616
# Iteration: 1305, Loss: 0.030524
# Iteration: 1306, Loss: 0.030563
# Iteration: 1307, Loss: 0.030521
# Iteration: 1308, Loss: 0.030515
# Iteration: 1309, Loss: 0.030513
# Iteration: 1310, Loss: 0.030511
# Iteration: 1311, Loss: 0.030509
# Iteration: 1312, Loss: 0.030508
# Iteration: 1313, Loss: 0.030505
# Iteration: 1314, Loss: 0.030500
# Iteration: 1315, Loss: 0.030493
# Iteration: 1316, Loss: 0.030546
# Iteration: 1317, Loss: 0.030490
# Iteration: 1318, Loss: 0.030483
# Iteration: 1319, Loss: 0.030478
# Iteration: 1320, Loss: 0.030481
# Iteration: 1321, Loss: 0.030471
# Iteration: 1322, Loss: 0.030468
# Iteration: 1323, Loss: 0.030466
# Iteration: 1324, Loss: 0.030459
# Iteration: 1325, Loss: 0.030453
# Iteration: 1326, Loss: 0.030446
# Iteration: 1327, Loss: 0.030613
# Iteration: 1328, Loss: 0.030444
# Iteration: 1329, Loss: 0.030440
# Iteration: 1330, Loss: 0.030434
# Iteration: 1331, Loss: 0.030431
# Iteration: 1332, Loss: 0.030426
# Iteration: 1333, Loss: 0.030421
# Iteration: 1334, Loss: 0.030414
# Iteration: 1335, Loss: 0.030402
# Iteration: 1336, Loss: 0.030396
# Iteration: 1337, Loss: 0.030388
# Iteration: 1338, Loss: 0.030380
# Iteration: 1339, Loss: 0.030372
# Iteration: 1340, Loss: 0.030371
# Iteration: 1341, Loss: 0.030366
# Iteration: 1342, Loss: 0.030389
# Iteration: 1343, Loss: 0.030362
# Iteration: 1344, Loss: 0.030355
# Iteration: 1345, Loss: 0.030347
# Iteration: 1346, Loss: 0.030344
# Iteration: 1347, Loss: 0.030335
# Iteration: 1348, Loss: 0.030393
# Iteration: 1349, Loss: 0.030333
# Iteration: 1350, Loss: 0.030326
# Iteration: 1351, Loss: 0.030317
# Iteration: 1352, Loss: 0.030311
# Iteration: 1353, Loss: 0.030304
# Iteration: 1354, Loss: 0.030300
# Iteration: 1355, Loss: 0.030296
# Iteration: 1356, Loss: 0.030307
# Iteration: 1357, Loss: 0.030294
# Iteration: 1358, Loss: 0.030291
# Iteration: 1359, Loss: 0.030289
# Iteration: 1360, Loss: 0.030286
# Iteration: 1361, Loss: 0.030284
# Iteration: 1362, Loss: 0.030282
# Iteration: 1363, Loss: 0.030280
# Iteration: 1364, Loss: 0.030278
# Iteration: 1365, Loss: 0.030275
# Iteration: 1366, Loss: 0.030272
# Iteration: 1367, Loss: 0.030272
# Iteration: 1368, Loss: 0.030270
# Iteration: 1369, Loss: 0.030267
# Iteration: 1370, Loss: 0.030262
# Iteration: 1371, Loss: 0.030258
# Iteration: 1372, Loss: 0.030254
# Iteration: 1373, Loss: 0.030251
# Iteration: 1374, Loss: 0.030247
# Iteration: 1375, Loss: 0.030243
# Iteration: 1376, Loss: 0.030236
# Iteration: 1377, Loss: 0.030231
# Iteration: 1378, Loss: 0.030311
# Iteration: 1379, Loss: 0.030230
# Iteration: 1380, Loss: 0.030460
# Iteration: 1381, Loss: 0.030221
# Iteration: 1382, Loss: 0.030215
# Iteration: 1383, Loss: 0.030207
# Iteration: 1384, Loss: 0.030197
# Iteration: 1385, Loss: 0.030192
# Iteration: 1386, Loss: 0.030184
# Iteration: 1387, Loss: 0.031699
# Iteration: 1388, Loss: 0.030186
# Iteration: 1389, Loss: 0.030182
# Iteration: 1390, Loss: 0.030175
# Iteration: 1391, Loss: 0.030170
# Iteration: 1392, Loss: 0.030164
# Iteration: 1393, Loss: 0.030159
# Iteration: 1394, Loss: 0.030152
# Iteration: 1395, Loss: 0.030147
# Iteration: 1396, Loss: 0.030143
# Iteration: 1397, Loss: 0.030141
# Iteration: 1398, Loss: 0.030139
# Iteration: 1399, Loss: 0.030137
# Iteration: 1400, Loss: 0.030133
# Iteration: 1401, Loss: 0.030131
# Iteration: 1402, Loss: 0.030130
# Iteration: 1403, Loss: 0.030126
# Iteration: 1404, Loss: 0.030120
# Iteration: 1405, Loss: 0.030110
# Iteration: 1406, Loss: 0.030105
# Iteration: 1407, Loss: 0.030100
# Iteration: 1408, Loss: 0.030097
# Iteration: 1409, Loss: 0.030096
# Iteration: 1410, Loss: 0.030093
# Iteration: 1411, Loss: 0.030243
# Iteration: 1412, Loss: 0.030092
# Iteration: 1413, Loss: 0.030088
# Iteration: 1414, Loss: 0.030085
# Iteration: 1415, Loss: 0.030081
# Iteration: 1416, Loss: 0.030074
# Iteration: 1417, Loss: 0.030066
# Iteration: 1418, Loss: 0.030146
# Iteration: 1419, Loss: 0.030064
# Iteration: 1420, Loss: 0.030054
# Iteration: 1421, Loss: 0.030048
# Iteration: 1422, Loss: 0.030042
# Iteration: 1423, Loss: 0.030036
# Iteration: 1424, Loss: 0.030028
# Iteration: 1425, Loss: 0.030023
# Iteration: 1426, Loss: 0.030011
# Iteration: 1427, Loss: 0.030000
# Iteration: 1428, Loss: 0.029984
# Iteration: 1429, Loss: 0.030000
# Iteration: 1430, Loss: 0.029968
# Iteration: 1431, Loss: 0.029953
# Iteration: 1432, Loss: 0.029944
# Iteration: 1433, Loss: 0.029933
# Iteration: 1434, Loss: 0.029927
# Iteration: 1435, Loss: 0.029999
# Iteration: 1436, Loss: 0.029905
# Iteration: 1437, Loss: 0.029887
# Iteration: 1438, Loss: 0.029873
# Iteration: 1439, Loss: 0.029864
# Iteration: 1440, Loss: 0.029860
# Iteration: 1441, Loss: 0.029856
# Iteration: 1442, Loss: 0.029854
# Iteration: 1443, Loss: 0.029852
# Iteration: 1444, Loss: 0.029849
# Iteration: 1445, Loss: 0.029847
# Iteration: 1446, Loss: 0.029850
# Iteration: 1447, Loss: 0.029846
# Iteration: 1448, Loss: 0.029845
# Iteration: 1449, Loss: 0.029843
# Iteration: 1450, Loss: 0.029841
# Iteration: 1451, Loss: 0.029838
# Iteration: 1452, Loss: 0.029841
# Iteration: 1453, Loss: 0.029837
# Iteration: 1454, Loss: 0.029834
# Iteration: 1455, Loss: 0.029832
# Iteration: 1456, Loss: 0.029828
# Iteration: 1457, Loss: 0.029887
# Iteration: 1458, Loss: 0.029827
# Iteration: 1459, Loss: 0.029824
# Iteration: 1460, Loss: 0.029819
# Iteration: 1461, Loss: 0.029816
# Iteration: 1462, Loss: 0.029813
# Iteration: 1463, Loss: 0.029811
# Iteration: 1464, Loss: 0.029809
# Iteration: 1465, Loss: 0.029807
# Iteration: 1466, Loss: 0.029804
# Iteration: 1467, Loss: 0.029801
# Iteration: 1468, Loss: 0.029798
# Iteration: 1469, Loss: 0.029796
# Iteration: 1470, Loss: 0.029793
# Iteration: 1471, Loss: 0.029792
# Iteration: 1472, Loss: 0.029790
# Iteration: 1473, Loss: 0.029789
# Iteration: 1474, Loss: 0.029786
# Iteration: 1475, Loss: 0.029802
# Iteration: 1476, Loss: 0.029785
# Iteration: 1477, Loss: 0.029785
# Iteration: 1478, Loss: 0.029783
# Iteration: 1479, Loss: 0.029784
# Iteration: 1480, Loss: 0.029783
# Iteration: 1481, Loss: 0.029781
# Iteration: 1482, Loss: 0.029779
# Iteration: 1483, Loss: 0.029778
# Iteration: 1484, Loss: 0.029776
# Iteration: 1485, Loss: 0.029774
# Iteration: 1486, Loss: 0.029773
# Iteration: 1487, Loss: 0.029771
# Iteration: 1488, Loss: 0.029768
# Iteration: 1489, Loss: 0.029766
# Iteration: 1490, Loss: 0.029760
# Iteration: 1491, Loss: 0.029757
# Iteration: 1492, Loss: 0.029751
# Iteration: 1493, Loss: 0.029747
# Iteration: 1494, Loss: 0.029744
# Iteration: 1495, Loss: 0.029740
# Iteration: 1496, Loss: 0.029737
# Iteration: 1497, Loss: 0.029733
# Iteration: 1498, Loss: 0.029734
# Iteration: 1499, Loss: 0.029731
# Iteration: 1500, Loss: 0.029727
# Iteration: 1501, Loss: 0.029723
# Iteration: 1502, Loss: 0.029713
# Iteration: 1503, Loss: 0.029707
# Iteration: 1504, Loss: 0.029698
# Iteration: 1505, Loss: 0.029693
# Iteration: 1506, Loss: 0.029685
# Iteration: 1507, Loss: 0.029674
# Iteration: 1508, Loss: 0.029665
# Iteration: 1509, Loss: 0.029732
# Iteration: 1510, Loss: 0.029661
# Iteration: 1511, Loss: 0.029652
# Iteration: 1512, Loss: 0.029645
# Iteration: 1513, Loss: 0.029641
# Iteration: 1514, Loss: 0.029635
# Iteration: 1515, Loss: 0.029630
# Iteration: 1516, Loss: 0.029626
# Iteration: 1517, Loss: 0.029620
# Iteration: 1518, Loss: 0.029615
# Iteration: 1519, Loss: 0.029612
# Iteration: 1520, Loss: 0.029649
# Iteration: 1521, Loss: 0.029609
# Iteration: 1522, Loss: 0.029600
# ...
# Iteration: 14163, Loss: 0.010009
# Iteration: 14164, Loss: 0.010007
# Iteration: 14165, Loss: 0.010006
# Iteration: 14166, Loss: 0.010005
# Iteration: 14167, Loss: 0.010004
# Iteration: 14168, Loss: 0.010004
# Iteration: 14169, Loss: 0.010004
# Iteration: 14170, Loss: 0.010003
# Iteration: 14171, Loss: 0.010003
# Iteration: 14172, Loss: 0.010002
# Iteration: 14173, Loss: 0.010002
# Iteration: 14174, Loss: 0.010001
# Iteration: 14175, Loss: 0.010000
# Iteration: 14176, Loss: 0.009999
# Iteration: 14177, Loss: 0.009998
# Iteration: 14178, Loss: 0.009998
# Iteration: 14179, Loss: 0.009996
# Iteration: 14180, Loss: 0.009996
# Iteration: 14181, Loss: 0.009995
# Iteration: 14182, Loss: 0.009994
# Iteration: 14183, Loss: 0.009994
# Iteration: 14184, Loss: 0.009993
# Iteration: 14185, Loss: 0.009993
# Iteration: 14186, Loss: 0.009991
# Iteration: 14187, Loss: 0.009990
# Iteration: 14188, Loss: 0.009989
# Iteration: 14189, Loss: 0.009988
# Iteration: 14190, Loss: 0.009988
# Iteration: 14191, Loss: 0.009987
# Iteration: 14192, Loss: 0.009987
# Iteration: 14193, Loss: 0.009986
# Iteration: 14194, Loss: 0.009986
# Iteration: 14195, Loss: 0.009985
# Iteration: 14196, Loss: 0.009985
# Iteration: 14197, Loss: 0.009984
# Iteration: 14198, Loss: 0.009984
# Iteration: 14199, Loss: 0.009983
# Iteration: 14200, Loss: 0.009982
# Iteration: 14201, Loss: 0.009981
# Iteration: 14202, Loss: 0.009980
# Iteration: 14203, Loss: 0.009979
# Iteration: 14204, Loss: 0.009979
# Iteration: 14205, Loss: 0.009978
# Iteration: 14206, Loss: 0.009977
# Iteration: 14207, Loss: 0.009976
# Iteration: 14208, Loss: 0.009976
# Iteration: 14209, Loss: 0.009975
# Iteration: 14210, Loss: 0.009975
# Iteration: 14211, Loss: 0.009974
# Iteration: 14212, Loss: 0.009973
# Iteration: 14213, Loss: 0.009981
# Iteration: 14214, Loss: 0.009973
# Iteration: 14215, Loss: 0.009972
# Iteration: 14216, Loss: 0.009970
# Iteration: 14217, Loss: 0.009968
# Iteration: 14218, Loss: 0.009967
# Iteration: 14219, Loss: 0.009965
# Iteration: 14220, Loss: 0.009964
# Iteration: 14221, Loss: 0.009964
# Iteration: 14222, Loss: 0.009963
# Iteration: 14223, Loss: 0.009963
# Iteration: 14224, Loss: 0.009962
# Iteration: 14225, Loss: 0.009962
# Iteration: 14226, Loss: 0.009961
# Iteration: 14227, Loss: 0.009961
# Iteration: 14228, Loss: 0.009960
# Iteration: 14229, Loss: 0.009959
# Iteration: 14230, Loss: 0.009958
# Iteration: 14231, Loss: 0.009957
# Iteration: 14232, Loss: 0.009956
# Iteration: 14233, Loss: 0.009954
# Iteration: 14234, Loss: 0.009959
# Iteration: 14235, Loss: 0.009954
# Iteration: 14236, Loss: 0.009953
# Iteration: 14237, Loss: 0.009953
# Iteration: 14238, Loss: 0.009952
# Iteration: 14239, Loss: 0.009951
# Iteration: 14240, Loss: 0.009949
# Iteration: 14241, Loss: 0.009949
# Iteration: 14242, Loss: 0.009948
# Iteration: 14243, Loss: 0.009947
# Iteration: 14244, Loss: 0.009947
# Iteration: 14245, Loss: 0.009946
# Iteration: 14246, Loss: 0.009946
# Iteration: 14247, Loss: 0.009945
# Iteration: 14248, Loss: 0.009944
# Iteration: 14249, Loss: 0.009960
# Iteration: 14250, Loss: 0.009944
# Iteration: 14251, Loss: 0.009943
# Iteration: 14252, Loss: 0.009942
# Iteration: 14253, Loss: 0.009941
# Iteration: 14254, Loss: 0.009940
# Iteration: 14255, Loss: 0.009940
# Iteration: 14256, Loss: 0.009939
# Iteration: 14257, Loss: 0.009938
# Iteration: 14258, Loss: 0.009936
# Iteration: 14259, Loss: 0.009934
# Iteration: 14260, Loss: 0.009932
# Iteration: 14261, Loss: 0.009931
# Iteration: 14262, Loss: 0.009930
# Iteration: 14263, Loss: 0.009929
# Iteration: 14264, Loss: 0.009927
# Iteration: 14265, Loss: 0.009926
# Iteration: 14266, Loss: 0.009925
# Iteration: 14267, Loss: 0.009924
# Iteration: 14268, Loss: 0.009924
# Iteration: 14269, Loss: 0.009923
# Iteration: 14270, Loss: 0.009922
# Iteration: 14271, Loss: 0.009921
# Iteration: 14272, Loss: 0.009921
# Iteration: 14273, Loss: 0.009920
# Iteration: 14274, Loss: 0.009920
# Iteration: 14275, Loss: 0.009919
# Iteration: 14276, Loss: 0.009918
# Iteration: 14277, Loss: 0.009917
# Iteration: 14278, Loss: 0.009918
# Iteration: 14279, Loss: 0.009916
# Iteration: 14280, Loss: 0.009915
# Iteration: 14281, Loss: 0.009914
# Iteration: 14282, Loss: 0.009914
# Iteration: 14283, Loss: 0.009914
# Iteration: 14284, Loss: 0.009913
# Iteration: 14285, Loss: 0.009912
# Iteration: 14286, Loss: 0.009912
# Iteration: 14287, Loss: 0.009911
# Iteration: 14288, Loss: 0.009911
# Iteration: 14289, Loss: 0.009910
# Iteration: 14290, Loss: 0.009910
# Iteration: 14291, Loss: 0.009910
# Iteration: 14292, Loss: 0.009909
# Iteration: 14293, Loss: 0.009908
# Iteration: 14294, Loss: 0.009907
# Iteration: 14295, Loss: 0.009906
# Iteration: 14296, Loss: 0.009905
# Iteration: 14297, Loss: 0.009904
# Iteration: 14298, Loss: 0.009904
# Iteration: 14299, Loss: 0.009903
# Iteration: 14300, Loss: 0.009903
# Iteration: 14301, Loss: 0.009902
# Iteration: 14302, Loss: 0.009902
# Iteration: 14303, Loss: 0.009901
# Iteration: 14304, Loss: 0.009900
# Iteration: 14305, Loss: 0.009905
# Iteration: 14306, Loss: 0.009900
# Iteration: 14307, Loss: 0.009899
# Iteration: 14308, Loss: 0.009899
# Iteration: 14309, Loss: 0.009899
# Iteration: 14310, Loss: 0.009898
# Iteration: 14311, Loss: 0.009900
# Iteration: 14312, Loss: 0.009898
# Iteration: 14313, Loss: 0.009897
# Iteration: 14314, Loss: 0.009896
# Iteration: 14315, Loss: 0.009895
# Iteration: 14316, Loss: 0.009894
# Iteration: 14317, Loss: 0.009893
# Iteration: 14318, Loss: 0.009892
# Iteration: 14319, Loss: 0.009891
# Iteration: 14320, Loss: 0.009890
# Iteration: 14321, Loss: 0.009890
# Iteration: 14322, Loss: 0.009889
# Iteration: 14323, Loss: 0.009888
# Iteration: 14324, Loss: 0.009887
# Iteration: 14325, Loss: 0.009886
# Iteration: 14326, Loss: 0.009886
# Iteration: 14327, Loss: 0.009885
# Iteration: 14328, Loss: 0.009884
# Iteration: 14329, Loss: 0.009884
# Iteration: 14330, Loss: 0.009884
# Iteration: 14331, Loss: 0.009884
# Iteration: 14332, Loss: 0.009883
# Iteration: 14333, Loss: 0.009883
# Iteration: 14334, Loss: 0.009883
# Iteration: 14335, Loss: 0.009884
# Iteration: 14336, Loss: 0.009883
# Iteration: 14337, Loss: 0.009882
# Iteration: 14338, Loss: 0.009882
# Iteration: 14339, Loss: 0.009881
# Iteration: 14340, Loss: 0.009880
# Iteration: 14341, Loss: 0.009879
# Iteration: 14342, Loss: 0.009878
# Iteration: 14343, Loss: 0.009878
# Iteration: 14344, Loss: 0.009878
# Iteration: 14345, Loss: 0.009877
# Iteration: 14346, Loss: 0.009876
# Iteration: 14347, Loss: 0.009877
# Iteration: 14348, Loss: 0.009876
# Iteration: 14349, Loss: 0.009875
# Iteration: 14350, Loss: 0.009875
# Iteration: 14351, Loss: 0.009874
# Iteration: 14352, Loss: 0.009874
# Iteration: 14353, Loss: 0.009873
# Iteration: 14354, Loss: 0.009873
# Iteration: 14355, Loss: 0.009873
# Iteration: 14356, Loss: 0.009872
# Iteration: 14357, Loss: 0.009872
# Iteration: 14358, Loss: 0.009872
# Iteration: 14359, Loss: 0.009872
# Iteration: 14360, Loss: 0.009871
# Iteration: 14361, Loss: 0.009870
# Iteration: 14362, Loss: 0.009869
# Iteration: 14363, Loss: 0.009869
# Iteration: 14364, Loss: 0.009868
# Iteration: 14365, Loss: 0.009867
# Iteration: 14366, Loss: 0.009866
# Iteration: 14367, Loss: 0.009866
# Iteration: 14368, Loss: 0.009865
# Iteration: 14369, Loss: 0.009864
# Iteration: 14370, Loss: 0.009863
# Iteration: 14371, Loss: 0.009862
# Iteration: 14372, Loss: 0.009861
# Iteration: 14373, Loss: 0.009864
# Iteration: 14374, Loss: 0.009860
# Iteration: 14375, Loss: 0.009860
# Iteration: 14376, Loss: 0.009859
# Iteration: 14377, Loss: 0.009858
# Iteration: 14378, Loss: 0.009858
# Iteration: 14379, Loss: 0.009858
# Iteration: 14380, Loss: 0.009858
# Iteration: 14381, Loss: 0.009857
# Iteration: 14382, Loss: 0.009857
# Iteration: 14383, Loss: 0.009857
# Iteration: 14384, Loss: 0.009857
# Iteration: 14385, Loss: 0.009856
# Iteration: 14386, Loss: 0.009855
# Iteration: 14387, Loss: 0.009854
# Iteration: 14388, Loss: 0.009853
# Iteration: 14389, Loss: 0.009853
# Iteration: 14390, Loss: 0.009852
# Iteration: 14391, Loss: 0.009851
# Iteration: 14392, Loss: 0.009850
# Iteration: 14393, Loss: 0.009850
# Iteration: 14394, Loss: 0.009849
# Iteration: 14395, Loss: 0.009849
# Iteration: 14396, Loss: 0.009848
# Iteration: 14397, Loss: 0.009848
# Iteration: 14398, Loss: 0.009848
# Iteration: 14399, Loss: 0.009847
# Iteration: 14400, Loss: 0.009846
# Iteration: 14401, Loss: 0.009846
# Iteration: 14402, Loss: 0.009845
# Iteration: 14403, Loss: 0.009845
# Iteration: 14404, Loss: 0.009844
# Iteration: 14405, Loss: 0.009843
# Iteration: 14406, Loss: 0.009842
# Iteration: 14407, Loss: 0.009841
# Iteration: 14408, Loss: 0.009841
# Iteration: 14409, Loss: 0.009841
# Iteration: 14410, Loss: 0.009841
# Iteration: 14411, Loss: 0.009840
# Iteration: 14412, Loss: 0.009840
# Iteration: 14413, Loss: 0.009840
# Iteration: 14414, Loss: 0.009839
# Iteration: 14415, Loss: 0.009839
# Iteration: 14416, Loss: 0.009838
# Iteration: 14417, Loss: 0.009837
# Iteration: 14418, Loss: 0.009836
# Iteration: 14419, Loss: 0.009836
# Iteration: 14420, Loss: 0.009835
# Iteration: 14421, Loss: 0.009834
# Iteration: 14422, Loss: 0.009835
# Iteration: 14423, Loss: 0.009834
# Iteration: 14424, Loss: 0.009832
# Iteration: 14425, Loss: 0.009832
# Iteration: 14426, Loss: 0.009831
# Iteration: 14427, Loss: 0.009830
# Iteration: 14428, Loss: 0.009830
# Iteration: 14429, Loss: 0.009829
# Iteration: 14430, Loss: 0.009828
# Iteration: 14431, Loss: 0.009828
# Iteration: 14432, Loss: 0.009828
# Iteration: 14433, Loss: 0.009827
# Iteration: 14434, Loss: 0.009826
# Iteration: 14435, Loss: 0.009825
# Iteration: 14436, Loss: 0.009826
# Iteration: 14437, Loss: 0.009825
# Iteration: 14438, Loss: 0.009825
# Iteration: 14439, Loss: 0.009824
# Iteration: 14440, Loss: 0.009823
# Iteration: 14441, Loss: 0.009822
# Iteration: 14442, Loss: 0.009820
# Iteration: 14443, Loss: 0.009820
# Iteration: 14444, Loss: 0.009819
# Iteration: 14445, Loss: 0.009818
# Iteration: 14446, Loss: 0.009817
# Iteration: 14447, Loss: 0.009829
# Iteration: 14448, Loss: 0.009817
# Iteration: 14449, Loss: 0.009817
# Iteration: 14450, Loss: 0.009816
# Iteration: 14451, Loss: 0.009815
# Iteration: 14452, Loss: 0.009814
# Iteration: 14453, Loss: 0.009813
# Iteration: 14454, Loss: 0.009812
# Iteration: 14455, Loss: 0.009812
# Iteration: 14456, Loss: 0.009810
# Iteration: 14457, Loss: 0.009810
# Iteration: 14458, Loss: 0.009808
# Iteration: 14459, Loss: 0.009807
# Iteration: 14460, Loss: 0.009807
# Iteration: 14461, Loss: 0.009806
# Iteration: 14462, Loss: 0.009806
# Iteration: 14463, Loss: 0.009805
# Iteration: 14464, Loss: 0.009805
# Iteration: 14465, Loss: 0.009804
# Iteration: 14466, Loss: 0.009806
# Iteration: 14467, Loss: 0.009803
# Iteration: 14468, Loss: 0.009803
# Iteration: 14469, Loss: 0.009803
# Iteration: 14470, Loss: 0.009802
# Iteration: 14471, Loss: 0.009801
# Iteration: 14472, Loss: 0.009800
# Iteration: 14473, Loss: 0.009800
# Iteration: 14474, Loss: 0.009800
# Iteration: 14475, Loss: 0.009799
# Iteration: 14476, Loss: 0.009799
# Iteration: 14477, Loss: 0.009799
# Iteration: 14478, Loss: 0.009798
# Iteration: 14479, Loss: 0.009797
# Iteration: 14480, Loss: 0.009797
# Iteration: 14481, Loss: 0.009796
# Iteration: 14482, Loss: 0.009795
# Iteration: 14483, Loss: 0.009795
# Iteration: 14484, Loss: 0.009795
# Iteration: 14485, Loss: 0.009794
# Iteration: 14486, Loss: 0.009794
# Iteration: 14487, Loss: 0.009793
# Iteration: 14488, Loss: 0.009792
# Iteration: 14489, Loss: 0.009792
# Iteration: 14490, Loss: 0.009791
# Iteration: 14491, Loss: 0.009790
# Iteration: 14492, Loss: 0.009790
# Iteration: 14493, Loss: 0.009789
# Iteration: 14494, Loss: 0.009789
# Iteration: 14495, Loss: 0.009788
# Iteration: 14496, Loss: 0.009787
# Iteration: 14497, Loss: 0.009810
# Iteration: 14498, Loss: 0.009787
# Iteration: 14499, Loss: 0.009786
# Iteration: 14500, Loss: 0.009785
# Iteration: 14501, Loss: 0.009784
# Iteration: 14502, Loss: 0.009784
# Iteration: 14503, Loss: 0.009783
# Iteration: 14504, Loss: 0.009783
# Iteration: 14505, Loss: 0.009782
# Iteration: 14506, Loss: 0.009781
# Iteration: 14507, Loss: 0.009780
# Iteration: 14508, Loss: 0.009783
# Iteration: 14509, Loss: 0.009779
# Iteration: 14510, Loss: 0.009779
# Iteration: 14511, Loss: 0.009778
# Iteration: 14512, Loss: 0.009777
# Iteration: 14513, Loss: 0.009776
# Iteration: 14514, Loss: 0.009775
# Iteration: 14515, Loss: 0.009774
# Iteration: 14516, Loss: 0.009773
# Iteration: 14517, Loss: 0.009773
# Iteration: 14518, Loss: 0.009772
# Iteration: 14519, Loss: 0.009772
# Iteration: 14520, Loss: 0.009771
# Iteration: 14521, Loss: 0.009770
# Iteration: 14522, Loss: 0.009776
# Iteration: 14523, Loss: 0.009770
# Iteration: 14524, Loss: 0.009769
# Iteration: 14525, Loss: 0.009768
# Iteration: 14526, Loss: 0.009768
# Iteration: 14527, Loss: 0.009767
# Iteration: 14528, Loss: 0.009765
# Iteration: 14529, Loss: 0.009764
# Iteration: 14530, Loss: 0.009763
# Iteration: 14531, Loss: 0.009762
# Iteration: 14532, Loss: 0.009761
# Iteration: 14533, Loss: 0.009761
# Iteration: 14534, Loss: 0.009761
# Iteration: 14535, Loss: 0.009760
# Iteration: 14536, Loss: 0.009760
# Iteration: 14537, Loss: 0.009759
# Iteration: 14538, Loss: 0.009758
# Iteration: 14539, Loss: 0.009765
# Iteration: 14540, Loss: 0.009758
# Iteration: 14541, Loss: 0.009757
# Iteration: 14542, Loss: 0.009757
# Iteration: 14543, Loss: 0.009757
# Iteration: 14544, Loss: 0.009756
# Iteration: 14545, Loss: 0.009755
# Iteration: 14546, Loss: 0.009754
# Iteration: 14547, Loss: 0.009753
# Iteration: 14548, Loss: 0.009753
# Iteration: 14549, Loss: 0.009753
# Iteration: 14550, Loss: 0.009752
# Iteration: 14551, Loss: 0.009752
# Iteration: 14552, Loss: 0.009751
# Iteration: 14553, Loss: 0.009750
# Iteration: 14554, Loss: 0.009749
# Iteration: 14555, Loss: 0.009749
# Iteration: 14556, Loss: 0.009749
# Iteration: 14557, Loss: 0.009749
# Iteration: 14558, Loss: 0.009748
# Iteration: 14559, Loss: 0.009748
# Iteration: 14560, Loss: 0.009748
# Iteration: 14561, Loss: 0.009747
# Iteration: 14562, Loss: 0.009746
# Iteration: 14563, Loss: 0.009748
# Iteration: 14564, Loss: 0.009746
# Iteration: 14565, Loss: 0.009745
# Iteration: 14566, Loss: 0.009745
# Iteration: 14567, Loss: 0.009744
# Iteration: 14568, Loss: 0.009746
# Iteration: 14569, Loss: 0.009744
# Iteration: 14570, Loss: 0.009743
# Iteration: 14571, Loss: 0.009742
# Iteration: 14572, Loss: 0.009742
# Iteration: 14573, Loss: 0.009741
# Iteration: 14574, Loss: 0.009741
# Iteration: 14575, Loss: 0.009740
# Iteration: 14576, Loss: 0.009739
# Iteration: 14577, Loss: 0.009739
# Iteration: 14578, Loss: 0.009738
# Iteration: 14579, Loss: 0.009737
# Iteration: 14580, Loss: 0.009738
# Iteration: 14581, Loss: 0.009736
# Iteration: 14582, Loss: 0.009735
# Iteration: 14583, Loss: 0.009734
# Iteration: 14584, Loss: 0.009735
# Iteration: 14585, Loss: 0.009734
# Iteration: 14586, Loss: 0.009733
# Iteration: 14587, Loss: 0.009733
# Iteration: 14588, Loss: 0.009732
# Iteration: 14589, Loss: 0.009731
# Iteration: 14590, Loss: 0.009731
# Iteration: 14591, Loss: 0.009730
# Iteration: 14592, Loss: 0.009729
# Iteration: 14593, Loss: 0.009729
# Iteration: 14594, Loss: 0.009729
# Iteration: 14595, Loss: 0.009728
# Iteration: 14596, Loss: 0.009727
# Iteration: 14597, Loss: 0.009727
# Iteration: 14598, Loss: 0.009726
# Iteration: 14599, Loss: 0.009729
# Iteration: 14600, Loss: 0.009725
# Iteration: 14601, Loss: 0.009724
# Iteration: 14602, Loss: 0.009723
# Iteration: 14603, Loss: 0.009722
# Iteration: 14604, Loss: 0.009725
# Iteration: 14605, Loss: 0.009722
# Iteration: 14606, Loss: 0.009721
# Iteration: 14607, Loss: 0.009721
# Iteration: 14608, Loss: 0.009759
# Iteration: 14609, Loss: 0.009720
# Iteration: 14610, Loss: 0.009720
# Iteration: 14611, Loss: 0.009718
# Iteration: 14612, Loss: 0.009717
# Iteration: 14613, Loss: 0.009716
# Iteration: 14614, Loss: 0.009716
# Iteration: 14615, Loss: 0.009715
# Iteration: 14616, Loss: 0.009715
# Iteration: 14617, Loss: 0.009716
# Iteration: 14618, Loss: 0.009715
# Iteration: 14619, Loss: 0.009714
# Iteration: 14620, Loss: 0.009714
# Iteration: 14621, Loss: 0.009714
# Iteration: 14622, Loss: 0.009714
# Iteration: 14623, Loss: 0.009713
# Iteration: 14624, Loss: 0.009713
# Iteration: 14625, Loss: 0.009712
# Iteration: 14626, Loss: 0.009713
# Iteration: 14627, Loss: 0.009712
# Iteration: 14628, Loss: 0.009711
# Iteration: 14629, Loss: 0.009710
# Iteration: 14630, Loss: 0.009709
# Iteration: 14631, Loss: 0.009709
# Iteration: 14632, Loss: 0.009708
# Iteration: 14633, Loss: 0.009707
# Iteration: 14634, Loss: 0.009706
# Iteration: 14635, Loss: 0.009705
# Iteration: 14636, Loss: 0.009704
# Iteration: 14637, Loss: 0.009709
# Iteration: 14638, Loss: 0.009704
# Iteration: 14639, Loss: 0.009703
# Iteration: 14640, Loss: 0.009703
# Iteration: 14641, Loss: 0.009702
# Iteration: 14642, Loss: 0.009702
# Iteration: 14643, Loss: 0.009701
# Iteration: 14644, Loss: 0.009701
# Iteration: 14645, Loss: 0.009700
# Iteration: 14646, Loss: 0.009700

# %%
PINN.net.eval()
# Out:
# DNN(
#   (model): Sequential(
#     (layer_0): Linear(in_features=3, out_features=700, bias=True)
#     (activation_0): Tanh()
#     (layer_1): Linear(in_features=700, out_features=700, bias=True)
#     (activation_1): Tanh()
#     (layer_2): Linear(in_features=700, out_features=2, bias=True)
#   )
# )

# %%
x_test = X_star.reshape(N, T, 3)[:, 0:1, 0]
y_test = X_star.reshape(N, T, 3)[:, 0:1, 1]
t_test = np.ones((x_test.shape[0], x_test.shape[1]))

x_test = torch.tensor(x_test, dtype=torch.float32, requires_grad=True).to(device)
y_test = torch.tensor(y_test, dtype=torch.float32, requires_grad=True).to(device)
t_test = torch.tensor(t_test, dtype=torch.float32, requires_grad=True).to(device)

# %%
u_out, v_out, p_out, f_out, g_out = PINN.function(x_test, y_test, t_test)

# %%
u_plot = u_out.data.cpu().numpy()
u_plot = np.reshape(u_plot, (89, 89))
usol = np.reshape(usol, (89, 89, 399))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# standardizing colorbar range
vmin = min(np.min(u_plot), np.min(usol))
vmax = max(np.max(u_plot), np.max(usol))

h = ax1.contourf(u_plot, levels=30, cmap='jet', vmin=vmin, vmax=vmax)
fig.colorbar(h, ax=ax1)

h = ax2.contourf(usol[:, :, 0], levels=30, cmap='jet', vmin=vmin, vmax=vmax)
fig.colorbar(h, ax=ax2)
plt.show()

def animate(i):
    ax1.clear()
    ax2.clear()
    u_out, v_out, f_out, g_out, h_out = PINN.function(x_test, y_test, 0.01*i*t_test)
    u_plot = u_out.data.cpu().numpy()
    u_plot = np.reshape(u_plot, (89, 89))
    cax = ax1.contourf(u_plot, levels=20, cmap='jet', vmin=vmin, vmax=vmax)
    cax = ax2.contourf(usol[:, :, i], levels=20, cmap='jet', vmin=vmin, vmax=vmax)
    ax1.set_xlabel(r'$x$')
    ax1.set_ylabel(r'$y$')
    ax2.set_xlabel(r'$x$')
    ax2.set_ylabel(r'$y$')
    ax1.set_title(r'Predicted $u(x, \; y, \;t)$')
    ax2.set_title(r'Ground truth $u(x, \;y, \;t)$')

ani = animation.FuncAnimation(fig, animate, 50, interval=1, blit=False)
f = os.path.join(out_dir, 'u_field_ns_weighted_ic.gif')
ani.save(f)
plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
v_plot = v_out.data.cpu().numpy()
v_plot = np.reshape(v_plot, (89, 89))
vsol = np.reshape(vsol, (89, 89, 399))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# standardizing colorbar range
vmin = min(np.min(v_plot), np.min(vsol))
vmax = max(np.max(v_plot), np.max(vsol))

h = ax1.contourf(v_plot, levels=30, cmap='jet', vmin=vmin, vmax=vmax)
fig.colorbar(h, ax=ax1)

h = ax2.contourf(vsol[:, :, 0], levels=30, cmap='jet', vmin=vmin, vmax=vmax)
fig.colorbar(h, ax=ax2)
plt.show()

def animate(i):
    ax1.clear()
    ax2.clear()
    u_out, v_out, f_out, g_out, h_out = PINN.function(x_test, y_test, 0.01*i*t_test)
    v_plot = v_out.data.cpu().numpy()
    v_plot = np.reshape(v_plot, (89, 89))
    cax = ax1.contourf(v_plot, levels=20, cmap='jet', vmin=vmin, vmax=vmax)
    cax = ax2.contourf(vsol[:, :, i], levels=20, cmap='jet', vmin=vmin, vmax=vmax)
    ax1.set_xlabel(r'$x$')
    ax1.set_ylabel(r'$y$')
    ax2.set_xlabel(r'$x$')
    ax2.set_ylabel(r'$y$')
    ax1.set_title(r'Predicted $v(x, \; y, \;t)$')
    ax2.set_title(r'Ground truth $v(x, \;y, \;t)$')

ani = animation.FuncAnimation(fig, animate, 50, interval=1, blit=False)
f = os.path.join(out_dir, 'v_field_ns_weighted_ic.gif')
ani.save(f)
plt.show()
# Out:
# c:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\animation.py:884: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
plt.plot(PINN.loss_history[:1000])
# plt.plot(PINN.loss_history)
plt.title("Total loss history")
plt.xlabel("Epochs")
plt.ylabel("Loss")
f = os.path.join(out_dir, 'total_loss_weighted.png')
plt.savefig(f, facecolor='white')

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
fig.tight_layout(pad=5.0)
ax1.plot(PINN.loss_history_f[:5000])
ax1.set_title('Loss history f')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')

ax2.plot(PINN.loss_history_g[:5000])
ax2.set_title('Loss history g')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')

ax3.plot(PINN.loss_history_u[:5000])
ax3.set_title('Loss history u')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Loss')

ax4.plot(PINN.loss_history_v[:5000])
ax4.set_title('Loss history v')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Loss')

f = os.path.join(out_dir, 'individual_loss_weighted.png')
plt.savefig(f, facecolor='white')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ed968cd69ff> in <module>
# ----> 1 fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
#       2 fig.tight_layout(pad=5.0)
#       3 ax1.plot(PINN.loss_history_f[:5000])
#       4 ax1.set_title('Loss history f')
#       5 ax1.set_xlabel('Epoch')
#
# NameError: name 'plt' is not defined

# %%
plt.plot(np.log10(PINN.loss_history))
# plt.plot(PINN.loss_history)
plt.title("Total log loss history")
plt.xlabel("Epochs")
plt.ylabel("Log Loss")
f = os.path.join(out_dir, 'total_log_loss_weighted.png')
plt.savefig(f, facecolor='white')

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
fig.tight_layout(pad=5.0)
ax1.plot(np.log10(PINN.loss_history_f))
ax1.set_title('Log Loss history f')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Log Loss')

ax2.plot(np.log10(PINN.loss_history_g))
ax2.set_title('Log Loss history g')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Log Loss')

ax3.plot(np.log10(PINN.loss_history_u))
ax3.set_title('Log Loss history u')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Log Loss')

ax4.plot(np.log10(PINN.loss_history_v))
ax4.set_title('Log Loss history v')
ax4.set_xlabel('Epoch')
ax4.set_ylabel('Log Loss')
f = os.path.join(out_dir, 'individual_log_loss_weighted.png')
plt.savefig(f, facecolor='white')

# %%
# calculate relative L2 error and MSE
error_u, error_v = 0, 0
mse_u, mse_v = 0, 0
for i in range(T):
    u_out, v_out, f_out, g_out, h_out = PINN.function(x_test, y_test, 0.01*i*t_test)
    usol_i = usol[:, :, i].reshape(N, 1)
    vsol_i = vsol[:, :, i].reshape(N, 1)
    u_out = u_out.detach().cpu().numpy()
    v_out = v_out.detach().cpu().numpy()

    # L2 error calculations
    error_u += np.linalg.norm(usol_i-u_out, 2) / np.linalg.norm(usol_i, 2)
    error_v += np.linalg.norm(vsol_i-v_out, 2) / np.linalg.norm(vsol_i, 2)

    # MSE calculations
    mse_u += np.square(usol_i-u_out).mean()
    mse_v += np.square(vsol_i-v_out).mean()

error_u /= T
error_v /= T

print('Relative L2 Error:\nL2 Error u: %e \nL2 Error v: %e' % (error_u, error_v))
print('MSE:\nMSE u: %e\nMSE v: %e' % (mse_u, mse_v))
# Out:
# Relative L2 Error:
# L2 Error u: 4.036979e-01
# L2 Error v: 7.038325e-01
# MSE:
# MSE u: 1.705938e+00
# MSE v: 2.633139e+00
